# %%
url='https://myanimelist.net/anime.php'
headers={'User-Agent':'Mozilla/5.0 (X11; Linux x86_64; rv:12.0) Gecko/20100101 Firefox/12.0'}
#r=requests.get(url,headers)
#soup=BeautifulSoup(r.text,'html.parser')
#response = requests.post(url, data=post_fields, timeout=timeout)
#print(response.elapsed.total_seconds())

# %%
import requests
from bs4 import BeautifulSoup
import string
import re
from bs4 import BeautifulSoup, NavigableString, Tag
import time  
import csv
import itertools

# %%
import pandas as pd
d=pd.read_csv('anime_details - Copy.csv',sep=',')
d.head()
# Out:
#    ID                             title  \
# 0   1                            ......
# 1   2              .hack//G.U. Returner
# 2   3               .hack//G.U. Trilogy
# 3   4  .hack//G.U. Trilogy: Parody Mode
# 4   5                       .hack//Gift
#
#                                                 link   code    rank  \
# 0              https://myanimelist.net/anime/56036/-  56036     NaN
# 1  https://myanimelist.net/anime/2928/hack__GU_Re...   2928  5654.0
# 2  https://myanimelist.net/anime/3269/hack__GU_Tr...   3269  3749.0
# 3  https://myanimelist.net/anime/4469/hack__GU_Tr...   4469  7382.0
# 4       https://myanimelist.net/anime/454/hack__Gift    454  8741.0
#
#    popularity  members  score  \
# 0     16550.0    391.0   6.54
# 1      4560.0  21419.0   6.67
# 2      3770.0  32490.0   7.08
# 3      6024.0  10706.0   6.36
# 4      4632.0  20703.0   6.10
#
#                                              summary             studio  \
# 0  Music video directed by obmolot for the song ....     {'FlatStudio'}
# 1  The characters from previous .hack//G.U. Games...       {'BeeTrain'}
# 2  Based on the CyberConnect2 HIT GAME, now will ...  {'CyberConnect2'}
# 3  A special bonus Parody Mode added to the extra...                NaN
# 4  As an expression of gratitude for the heroes o...       {'BeeTrain'}
#
#    episode                           producer  \
# 0      1.0                                NaN
# 1      1.0  {'BandaiVisual', 'CyberConnect2'}
# 2      1.0                   {'BandaiVisual'}
# 3      1.0                   {'BandaiVisual'}
# 4      1.0                  {'CyberConnect2'}
#
#                                 licensor                              genre  \
# 0                                    NaN         {'Horror', 'Supernatural'}
# 1                                    NaN  {'Drama', 'Adventure', 'Fantasy'}
# 2  {'Funimation', 'BandaiEntertainment'}              {'Fantasy', 'Action'}
# 3                                    NaN    {'Fantasy', 'Comedy', 'Sci-Fi'}
# 4                {'BandaiEntertainment'}              {'Fantasy', 'Comedy'}
#
#                theme  duration  \
# 0          {'Music'}       2.0
# 1  {'Video', 'Game'}      24.0
# 2  {'Video', 'Game'}     133.0
# 3                NaN       6.0
# 4  {'Video', 'Game'}      26.0
#
#                                               imgsrc  Unnamed: 17  Unnamed: 18
# 0  https://cdn.myanimelist.net/images/anime/1057/...          NaN          4.0
# 1  https://cdn.myanimelist.net/images/anime/1798/...          NaN          2.0
# 2  https://cdn.myanimelist.net/images/anime/4/230...          NaN          1.0
# 3  https://cdn.myanimelist.net/images/anime/10/86...          NaN          4.0
# 4  https://cdn.myanimelist.net/images/anime/2/230...          NaN          1.0

# %%
def reviews(code,morereviews):
    #print('passed: '+morereviews)
    #print("review start")
    r=requests.get(morereviews,headers)
    soup=BeautifulSoup(r.text,'html.parser')
    T=30
    #print('P1')
    while r.status_code!=200:
            print("status czode")
            print(r.status_code)
            time.sleep(T)
            r=requests.get(morereviews,headers)
            #print(r.text)
            soup=BeautifulSoup(r.text,'html.parser')
            T=T+20
            print(morereviews)       
            if T>350:
                break
            
    a=soup.find_all('div',{'class':'review-element js-review-element'})
    k=morereviews
    try:
        for i in soup.find_all('div',{'class':'ml4 mb8'}):
            morereviews=i.find('a')['href']
            break
        else:       
            morereviews=''
    except:
        morereviews=''
    review={}
    for i in a:
        review[i.find('div',{'class':'username'}).text]=i.find('div',{'class':'text'}).text
        
    Allreviews[code]=review 
    if morereviews!='' and k!=morereviews:
       
        reviews(code,morereviews)
        #print('empty')

# %%
def Letterswisesearch(Detailscounter,details):
    Alphabets=('T','U','V','W','X','Y','Z')

    
    for alpha in Alphabets:
        r=requests.get(url+'?letter='+alpha,headers)
        #print("main status code")
        #print(r.status_code)

        soup=BeautifulSoup(r.text,'html.parser')
        T=30
        while(r.status_code!=200):
            print("status code")
            print(r.status_code)
            time.sleep(T)
            T=T+20
            r=requests.get(url+'?letter='+alpha,headers)
            soup=BeautifulSoup(r.text,'html.parser')

       # print(soup.prettify)
        table=soup.find('div',{'class':'js-categories-seasonal'}).find_all('tr')

        #re.sub('[^0-9]', '-',pageno.get_attribute("innerText"))).split("-")
        #num=list(re.sub('[^0-9]','',num[0]))
        substring='anime/'
        for i in table:
            innerdict={}

            for j in i.find_all('a',{'class':'hoverinfo_trigger fw-b fl-l'}):
                names.append(j.text)
                href.append(j['href'])
                innerdict['title']=j.text 
                innerdict['link']=j['href']
                Detailscounter=Detailscounter+1
                index=j['href'].index(substring)+len(substring)
                code=''  
                while(j['href'][index]!='/'):
                    code=code+j['href'][index]
                    index=index+1

                innerdict['code']=code
                details[Detailscounter]=innerdict    

               # print(alpha)
                Animedetails(Detailscounter,j['href'],details)
                #print('main one: '+j['href'])


                print(details[Detailscounter]['title'])
                #print("Reviews start")
              #  reviews(int(code),j['href']+'/reviews?sort=suggested&filter_check=&filter_hide=&preliminary=on&spoiler=on&p=1')

                #print(alpha+"Animereviews")

                #innerdict.clear()
                #print(Detailscounter)

        EverysinglePage(findtotalpage(soup),Detailscounter,alpha,50,details,count=1)   

        #print(alpha+" "+str(numi)+"Animedetails")
       

        Allreviews={}

# %%
def findtotalpage(soup):
    num=0
    pages=soup.find_all('span',{'class':'bgColor1'})
    
    for i in pages:
        if i.text[-2]==' ':
            num=int(i.text[-1])
        elif i.text[-3]==' ' and i.text!=' ':
            num=int(i.text[-2]+i.text[-1])
    
    return num

# %%
def EverysinglePage(num,Detailscounter,alpha,previousnum,details,count):
    
    startnum=previousnum
    pagelist=range(startnum,num*50,50)
    

    #pagelist=range(50,100,50)
    for numi in pagelist:
        #headers={'User-Agent':'Mozilla/5.0 (X11; Linux x86_64; rv:12.0) Gecko/20100101 Firefox/12.0'}
        if count==3:
            count=0
            print("sleeping")
            time.sleep(30)
        count+=1
        T=30
        r=requests.get(url+'?letter='+alpha+'&show='+str(numi),headers)
        #print("status code")
        #print(r.status_code)
        while r.status_code!=200:
            
            print("sleeping")
            time.sleep(T)
            r=requests.get(url+'?letter='+alpha+'&show='+str(numi),headers)
           
            T=T+20
            print("status code")
            print(r.status_code)
        soup=BeautifulSoup(r.text,'html.parser')
       # print(numi)
        global z
        z=soup
        #print(numi)
        table=soup.find('div',{'class':'js-categories-seasonal'}).find_all('tr')
        substring='anime/'
       # print(alpha+" "+str(numi))
        for i in table:
            innerdict={}
            for j in i.find_all('a',{'class':'hoverinfo_trigger fw-b fl-l'}):
              #  names.append(j.text)
               # href.append(j['href'])
                innerdict['title']=j.text 
                innerdict['link']=j['href']
                index=j['href'].index(substring)+len(substring)
                code=''  
                while(j['href'][index]!='/'):
                    code=code+j['href'][index]
                    index=index+1
                
                innerdict['code']=code
                
                Detailscounter=Detailscounter+1
                details[Detailscounter]=innerdict
                Animedetails(Detailscounter,j['href'],details)
                print(details[Detailscounter]['title'])
                #print(alpha+" "+str(numi)+"Animedetails")
                #reviews(int(code),j['href']+'/reviews?sort=suggested&filter_check=&filter_hide=&preliminary=on&spoiler=on&p=1')
               # print(alpha+" "+str(numi)+"Animereviews")
                #print(details[Detailscounter])
                #innerdict.clear()
       # print('OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO')
       # print(details[Detailscounter])
       # print('numi   num')
       # print(str(numi)+str(num))
        store(details)
        details.clear()
    NUM=findtotalpage(soup)
    if num < NUM:
        previousnum=num
        #print("once")
        EverysinglePage(NUM,Detailscounter,alpha,previousnum*50,details,count)

# %%
def Animedetails(key,url,details):
    t=30
    r=requests.get(url,headers)
    soup=BeautifulSoup(r.text,'html.parser')
    while(r.status_code!=200):
        print("status code")
        print(r.status_code)
        time.sleep(t)
        t=t+20
        r=requests.get(url,headers)
        soup=BeautifulSoup(r.text,'html.parser')
        
    print("status code")
    print(r.status_code)
    #print(soup.find_all('span',{'class':'numbers ranked'}))
    for i in soup.find_all('span',{'class':'numbers ranked'}):
        details[key]['Rank']=re.sub('[^0-9]','',i.text)
    for i in soup.find_all('span',{'class':'numbers popularity'}):
        details[key]['Popularity']=re.sub('[^0-9]','',i.text)
    for i in soup.find_all('span',{'class':'numbers members'}):
        details[key]['Members']=re.sub('[^0-9]','',i.text)
    for i in soup.find_all('span',{'itemprop':'ratingValue'}):
        details[key]['Score']=i.text
    for i in soup.find_all('p',{'itemprop':'description'}):
        details[key]['summary']=i.text
    for i in soup.find_all('span',{'class':'information studio author'}):
        details[key]['Studio']=i.text


    for i in soup.find_all('div',{'class':'spaceit_pad'}):
        if 'Episodes:' in i.text:
             details[key]['Episode']=re.sub('[^0-9]','',i.text)
        elif 'Producers' in i.text:
            a=set(i.text.replace(' ','-').replace('Producers:','').replace('\n','').replace('-','').split(','))
            a.discard('addsome')
            if 'Nonefound' in a:
                details[key]['Producer']=''
            else:
                details[key]['Producer']=a
        elif 'Licensors:' in i.text:
            a=set(i.text.replace(' ','-').replace('Licensors:','').replace('\n','').replace('-','').split(','))
            a.discard('addsome')
            if 'Nonefound' in a:
                details[key]['Licensor:']=''
            else:
                details[key]['Licensor:']=a
            
        elif 'Studios:' in i.text:
            a=set(i.text.replace(' ','-').replace('Studios:','').replace('\n','').replace('-','').split(','))
            a.discard('addsome')
            if 'Nonefound' in a:
                details[key]['Studio']=''
            else:
                details[key]['Studio']=a
        elif 'Genres:' in i.text:
            a=''
            for j in i.find_all('a'):
                a=a+' '+j.text
            m=set(a.split(' '))
            details[key]['Genre']=m-{''}
        elif 'Theme:' in i.text:
            a=''
            for j in i.find_all('a'):
                a=a+''+j.text
            m=set(a.split(' '))
            details[key]['Theme']=m-{''}
        elif 'Duration:' in i.text:
            details[key]['Duration']=re.sub('[^0-9]','',i.text)
      
    r=requests.get(url,headers)
    soup=BeautifulSoup(r.text,'html.parser')

    t=30

    while(r.status_code!=200):
        print("status code")
        print(r.status_code)
        time.sleep(t)
        t=t+20
        r=requests.get(url,headers)
        soup=BeautifulSoup(r.text,'html.parser')

    src=''
    try:
        for i in soup.find_all('h1',{'class':'title-name h1_bold_none'}):

            src=str(i.text)

        image=soup.find_all('img',{'alt':src})
        ind=str(image).index("data-src")+len('data-src')+2
        image=str(image)
        src=''
        while image[ind]!='"':
            src=src+image[ind]
            ind+=1
        details[key]['imgsrc']=src
    except:
        print("Nameeeeeeeeeee:")
        print(src)
        print('url')
        print(url)
        print(soup.find_all('h1',{'class':'title-name h1_bold_none'}))

# %%
def store(details):
    print("first")
    print(list(details)[0])
    print("last")
    print(list(details)[-1])
    previous=details
    csvfile(details)
            #reviewst(Allreviews)
    print('clearrrrrrrrr')
    details.clear()
    print(details)

# %%
Letterswisesearch(Detailscounter,details)
# Out:
# status code
# 200
# T
# status code
# 200
# T-Rex
# status code
# 200
# T-sensei
# status code
# 200
# T.P BON
# status code
# 200
# T.P. Sakura: Time Paladin Sakura
# status code
# 200
# T7S Longing for Summer Again and Again: Harukaze
# status code
# 200
# Ta Bu Dang Nuzhu Hen Duo Nian
# status code
# 200
# Ta ga Tame no Alchemist
# status code
# 200
# Taa-chan no Kaitei Ryokou
# status code
# 200
# Taabou no Ganbaru Sengen
# status code
# 200
# Taabou no Ryuuguusei Daitanken
# status code
# 200
# Tabechatta tte Ii no ni na!
# status code
# 200
# Taberu Hito-tachi
# status code
# 200
# Tabeta no Daare
# status code
# 200
# Tabi
# status code
# 200
# Tabi Machi Late Show
# status code
# 200
# Tabi no Kisetsu
# status code
# 200
# Tabi wa Michizure Yo wa Nasake
# status code
# 200
# Tabi wa ni
# status code
# 200
# Tabibito no You ni
# status code
# 200
# Tabidachi no Hi ni
# status code
# 200
# Tabidachi: Ami Shuushou
# status code
# 200
# Tabisuru Nuigurumi: Traveling Daru
# status code
# 200
# Taboo Tattoo
# status code
# 200
# Tabun
# status code
# 200
# Tachibanakan Triangle
# status code
# 200
# Tachiguishi Retsuden
# status code
# 200
# TaChiTsuTeTo Te wo
# status code
# 200
# Tachumaru Gekijou
# status code
# 200
# Tactical Roar
# status code
# 200
# Tactical Roar: Mercurius no Kyuujitsu
# status code
# 200
# Tactics
# status code
# 200
# Tada-kun wa Koi wo Shinai
# status code
# 200
# Tadaima Shiawase
# status code
# 200
# Tadaima! Chibi Godzilla
# status code
# 200
# Tadaima! Chibi Godzilla Season 2
# status code
# 200
# Tadaima, Okaeri
# status code
# 200
# Tadaima.
# status code
# 200
# Tadashii Itsuwari kara no Kishou
# status code
# 200
# Tadashiku Narenai
# status code
# 200
# Tae-il
# status code
# 200
# Taegeugsonyeon Huin Dogsuli
# status code
# 200
# Taeko no Nichijou
# status code
# 200
# Taeko no Nichijou 2nd Season
# status code
# 200
# Taekwon Dongja Maruchi Arachi
# status code
# 200
# Taekwon-wang Gang Taepung
# status code
# 200
# Taeng-gu & Ulasyong
# status code
# 200
# Tai Hao Fuxi
# status code
# 200
# Tai Ji Xiong
# status code
# 200
# Tai Lao Niangniang Yu Baicha Xianzi
# status code
# 200
# Tai Lyu
# status code
# 200
# Tai Yi Jian Xian Chuan
# status code
# 200
# Tai Yi Xian Mo Lu: Ling Fei Ji
# status code
# 200
# Tai Yi Xian Mo Lu: Ling Fei Ji II
# status code
# 200
# Tai Yi Xian Mo Lu: Ling Fei Ji III
# status code
# 200
# Tai Yi Xian Mo Lu: Ling Fei Ji IV
# status code
# 200
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 429
# Tai-Ari deshita.: Ojousama wa Kakutou Game nante Shinai
# status code
# 200
# Taiban!
# status code
# 200
# Taichi  Xiongmao
# status code
# 200
# Taichi Senjimon
# status code
# 200
# Taifuu 14-gou
# status code
# 200
# Taifuu no Noruda
# status code
# 200
# Taigong Qi Shu
# status code
# 200
# Taiheiyou ni Kakeru Niji
# status code
# 200
# Taihen da
# status code
# 200
# Taiho Shichau zo
# status code
# 200
# Taiho Shichau zo (TV)
# status code
# 200
# Taiho Shichau zo in America
# status code
# 200
# Taiho Shichau zo Special
# status code
# 200
# Taiho Shichau zo The Movie
# status code
# 200
# Taiho Shichau zo: Full Throttle
# status code
# 200
# Taiho Shichau zo: Full Throttle - Watashitachi no Iru Basho
# status code
# 200
# Taiho Shichau zo: Nagisa no Koutsuu Yuudou
# status code
# 200
# Taiho Shichau zo: Second Season
# status code
# 200
# Taihu Shaonian
# status code
# 200
# Taiji Kedou Chengzhang Ji: Baishi Xi Wu Pian
# status code
# 200
# Taiji Xiao Zi
# status code
# 200
# Taiko no Tatsujin
# status code
# 200
# Taiko no Tatsujin Anime Ba-Jon!
# status code
# 200
# Taiko no Tatsujin: 15-shuunen Kinen Short Animation
# status code
# 200
# Taikong Lixianji
# status code
# 200
# Taikong Tejing
# status code
# 200
# Taikong Xiha Zu
# status code
# 200
# Taikong Xiongmao Lixian Ji
# status code
# 200
# Taikong Xiongmao Yingxiong Dansheng
# status code
# 200
# Taikong Xiongmao Yingxiong Guilai
# status code
# 200
# Taikong Xiongmao Zongdongyuan
# status code
# 200
# Taikong Xueyuan
# status code
# 200
# Taikutsu wo Saien Shinaide
# status code
# 200
# Tailenders
# status code
# 200
# Taimadou Gakuen 35 Shiken Shoutai
# status code
# 200
# Taiman Blues: Ladies-hen - Mayumi
# status code
# 200
# Taiman Blues: Shimizu Naoto-hen
# status code
# 200
# Taimanin Asagi
# status code
# 200
# Taimanin Asagi 2
# status code
# 200
# Taimanin Asagi 3
# status code
# 200
# Taimanin Asagi Special
# status code
# 200
# Taimanin Asagi: Toraware no Niku Ningyou
# status code
# 200
# Taimanin Shiranui: Inyoku no Dorei Shoufu
# status code
# 200
# Taimanin Yukikaze
# first
# 1
# last
# 100
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Taimanin Yukikaze Special
# status code
# 200
# Tairiki Tarou no Mucha Shuugyou
# status code
# 200
# Taisei Kensetsu CMs
# status code
# 200
# Taisetsu na Kazoku wo Tsutsumu, Sono Te.
# status code
# 200
# Taishou Mebiusline: Chicchai-san
# status code
# 200
# Taishou Mebiusline: Chicchai-san - You and I
# status code
# 200
# Taishou Otome Otogibanashi
# status code
# 200
# Taishou Roman
# status code
# 200
# Taishou Yakyuu Musume.
# status code
# 200
# Taishou Yakyuu Musume. Specials
# status code
# 200
# Taisou Zamurai
# status code
# 200
# Taiyang Baobei: Chengyu Xin Shuo
# status code
# 200
# Taiyang de Xiao Keren
# status code
# 200
# Taiyang Liu Zhu Wo
# status code
# 200
# Taiyang Shizhe
# status code
# 200
# Taiyang Zhizi
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Taiyo Kikaku's 49th Anniversary Movie
# status code
# 200
# Taiyou no Hou: El Cantare e no Michi
# status code
# 200
# Taiyou no Kiba Dagram
# status code
# 200
# Taiyou no Ko Esteban
# status code
# 200
# Taiyou no Mokushiroku: A Spirit of the Sun
# status code
# 200
# Taiyou no Ouji: Horus no Daibouken
# status code
# 200
# Taiyou no Yuusha Fighbird
# status code
# 200
# Taiyou to Tsuki no Kodomo-tachi
# status code
# 200
# Taiyou to Tsuki no Kodomo-tachi (2018)
# status code
# 200
# Taka no Tsume 7: Joou Heika no Jobuubu
# status code
# 200
# Taka no Tsume 8: Yoshida-kun no Batten File
# status code
# 200
# Taka no Tsume GO: Utsukushiki Elleair Shoushuu Plus
# status code
# 200
# Taka no Tsume NEO Announcement Movie
# status code
# 200
# Taka no Tsume x Ballad Katte ni Senden Movie
# status code
# 200
# Taka no Tsume x Hello Kitty ga Masaka no Collab!
# status code
# 200
# Taka no Tsume x Johnson: Tatakae! Jokin Shitennou
# status code
# 200
# Taka no Tsume x Megane Super
# status code
# 200
# Taka no Tsume Yoshida-kun Batten File: Natsuyasumi Mystery Adventure
# status code
# 200
# Taka no Tsume: Tokyo Comic Con 2017 no Ouendan ni Shuunin Kettei!
# status code
# 200
# Taka no Tsumedan no Ike! ODAman
# status code
# 200
# Taka no Tsumedan x Uchicomi!
# status code
# 200
# Taka no Tsumedan Yoshida Presents "Sengoku Taiga" no Susume
# status code
# 200
# Taka no Tsumedan, Toyama
# status code
# 200
# Takahashi Rumiko Gekijou
# status code
# 200
# Takahashi Rumiko Gekijou Ningyo no Mori
# status code
# 200
# Takamiya Nasuno desu! Teekyuu Spin-off
# status code
# 200
# Takamiya Nasuno desu! Teekyuu Spin-off Special
# status code
# 200
# Takanashi Rikka Kai: Chuunibyou demo Koi ga Shitai! Movie
# status code
# 200
# Takanashi Rikka Kai: Chuunibyou demo Koi ga Shitai! Movie Lite
# status code
# 200
# Takane no Jitensha
# status code
# 200
# Takano Kousaten
# status code
# 200
# Takara Sagashi
# status code
# 200
# Takara-sagashi
# status code
# 200
# Takarajima
# first
# 101
# last
# 150
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# sleeping
# status code
# 200
# Takarajima Memorial: Yuunagi to Yobareta Otoko
# status code
# 200
# Takarajima Movie
# status code
# 200
# Takarakuji x Rope
# status code
# 200
# Takaramono
# status code
# 200
# Takarasagashi no Natsuyasumi
# status code
# 200
# Takate
# status code
# 200
# Take It Easy
# status code
# 200
# Take Your Way
# status code
# 200
# Takemoto Denki x Peeping Life
# status code
# 200
# Tako ni Natta Okaasan
# status code
# 200
# Tako no Hone
# status code
# 200
# Takoru the Movie
# status code
# 200
# Takoru TV
# status code
# 200
# Takoyaki Mant-Man
# status code
# 200
# Takoyaki Story
# status code
# 200
# Takt Op. Destiny
# status code
# 200
# Taku Boda
# status code
# 200
# Takunomi.
# status code
# 200
# Talala
# status code
# 200
# Tales of Crestoria
# status code
# 200
# Tales of Crestoria Off Shot Movie
# status code
# 200
# Tales of Crestoria: Toga Waga wo Shoite Kare wa Tatsu
# status code
# 200
# Tales of Eternia The Animation
# status code
# 200
# Tales of Gekijou
# status code
# 200
# Tales of HR
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Tales of Luminaria: The Fateful Crossroad
# status code
# 200
# Tales of Phantasia The Animation
# status code
# 200
# Tales of Puppet
# status code
# 200
# Tales of Symphonia The Animation: Kaette Kita Kratos-sensei no Private Lesson
# status code
# 200
# Tales of Symphonia The Animation: Kratos-sensei no Private Lesson
# status code
# 200
# Tales of Symphonia The Animation: Sekai Tougou-hen
# status code
# 200
# Tales of Symphonia The Animation: Sekai Tougou-hen Specials
# status code
# 200
# Tales of Symphonia The Animation: Sylvarant-hen
# status code
# 200
# Tales of Symphonia The Animation: Tethe'alla-hen
# status code
# 200
# Tales of Symphonia The Animation: Tethe'alla-hen Specials
# status code
# 200
# status code
# 429
# Tales of the Abyss
# status code
# 200
# Tales of the Abyss Special Fan Disc
# status code
# 200
# Tales of the Rays
# status code
# 200
# Tales of the Rays Gekijou
# status code
# 200
# Tales of the Rays: Everlasting Destiny
# status code
# 200
# Tales of Vesperia: The First Strike
# status code
# 200
# Tales of Zestiria the Cross
# status code
# 200
# Tales of Zestiria the Cross 2nd Season
# status code
# 200
# Tales of Zestiria the Cross: Saiyaku no Jidai
# status code
# 200
# Tales of Zestiria: Doushi no Yoake
# status code
# 200
# Talk with God
# status code
# 200
# Talpy
# status code
# 200
# Tama & Friends: Sagase! Mahou no Punipuni Stone
# status code
# 200
# Tama & Friends: Uchi no Tama Shirimasen ka?
# status code
# 200
# Tama Gura Abayo: Moki Yumokyu Superdeluxe
# first
# 151
# last
# 200
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Tama Pawns
# status code
# 200
# Tamagawa Kyoudai
# status code
# 200
# Tamago Niichan
# status code
# 200
# Tamagotchi Honto no Hanashi
# status code
# 200
# Tamagotchi Movie: Tanpen Himitsu no Otodoke Daisakusen!
# status code
# 200
# Tamagotchi!
# status code
# 200
# Tamagotchi! Miracle Friends
# status code
# 200
# Tamagotchi! Special DVD
# status code
# 200
# Tamagotchi! Tamatomo Daishuu GO
# status code
# 200
# Tamagotchi! x Taka no Tsume: Tamagotchi de Seikai Seifuku
# status code
# 200
# Tamagotchi! Yume Kira Dream
# status code
# 200
# Tamako Love Story
# status code
# 200
# Tamako Market
# status code
# 200
# Tamako Market Specials
# status code
# 200
# Tamala 2010: A Punk Cat in Space
# status code
# 200
# Tamala 2010: A Punk Cat in Space OVA
# status code
# 200
# Tamashichi!
# status code
# 200
# Tamashii Insert
# status code
# 429
# status code
# 200
# Tamaya CM: Sono Saki e-hen
# status code
# 200
# Tamaya CM: Takusareta Omoi-hen
# status code
# 200
# Tamaya Shichiten Tanjoubi-hen CM
# status code
# 200
# Tamayomi
# status code
# 200
# Tamayura
# status code
# 200
# Tamayura no Yume
# status code
# 200
# Tamayura: Hitotose
# status code
# 200
# Tamayura: Hitotose - Attakai Kaze no Omoide, nanode
# status code
# 200
# Tamayura: More Aggressive
# status code
# 200
# Tamayura: More Aggressive - Tsuitachi dake no Shuugakuryokou, nanode
# status code
# 200
# Tamayura: More Aggressive Picture Drama
# status code
# 200
# Tamayura: Sotsugyou Shashin Part 1 - Kizashi
# status code
# 200
# Tamayura: Sotsugyou Shashin Part 2 - Hibiki
# status code
# 200
# Tamayura: Sotsugyou Shashin Part 3 - Akogare
# status code
# 200
# Tamayura: Sotsugyou Shashin Part 4 - Ashita
# status code
# 200
# Tan Tan Mao: Qihuan Maxi Tuan
# status code
# 200
# Tan Tan Mao: Qihuan Maxi Tuan 2
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Tan Tan Mao: Qimiao Shijie
# status code
# 200
# Tan Tan Mao: Qimiao Shijie 2nd Season
# status code
# 200
# Tan Tan Tan
# status code
# 200
# Tan Zhang QiQi
# status code
# 200
# Nameeeeeeeeeee:
# Tana wo Tsukurimashou
# url
# https://myanimelist.net/anime/56833/Tana_wo_Tsukurimashou
# [<h1 class="title-name h1_bold_none"><strong>Tana wo Tsukurimashou</strong></h1>]
# Tana wo Tsukurimashou
# status code
# 200
# Tanaami Keiichi no Shouzou
# status code
# 200
# Tanabata Monogatari
# status code
# 200
# Tanabata no Oto
# status code
# 200
# Tanahashi Hiroshi X Mameshiba Pro Wrestling
# status code
# 200
# Tanaka-kun wa Itsumo Kedaruge
# status code
# 200
# Tanaka-kun wa Itsumo Kedaruge Specials
# status code
# 200
# Tanaka-kun wa Kyou mo Kedaruge
# status code
# 200
# Tanbai Haru, Tookaraji
# status code
# 200
# Tandemoon Rendezvous
# status code
# 200
# Taneko no Waltz
# first
# 201
# last
# 250
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Tanetsuke Ojisan to NTR Hitozuma Sex The Animation
# status code
# 200
# Tanetsuke Ojisan to Papakko JD Saimin Seikatsu The Animation
# status code
# 200
# Taneyamagahara no Yoru
# status code
# 200
# Tang Dou Wawa
# status code
# 200
# Tang Lang Bu Chan
# status code
# 200
# Tangguo Taikong Aoyou Ji: Nengliang Zhi Xing
# status code
# 200
# Tangguo Taikong Aoyou Ji: Xingqiu Chong Su
# status code
# 200
# Tangshi Gushi
# status code
# 200
# Tanin no Kankei
# status code
# 200
# Tanita Shokudou
# status code
# 429
# status code
# 200
# Tanitsu Shikousei Overbloom
# status code
# 200
# Tanjou
# status code
# 200
# Tanjou!! KKT21
# status code
# 200
# Tanjou: Debut
# status code
# 200
# Tanjoubi no Chachacha
# status code
# 200
# TANK S.W.A.T. 01
# status code
# 200
# Tanken Driland
# status code
# 200
# Tanken Driland: 1000-nen no Mahou
# status code
# 200
# Tannishou wo Hiraku
# status code
# 200
# Tanoshii Bunmeishi: Tetsu Monogatari
# status code
# 200
# Tanoshii Ekaki Uta
# status code
# 200
# Tanoshii Gakkou Seikatsu
# status code
# 200
# Tanoshii Muumin Ikka
# status code
# 200
# Tanoshii Muumin Ikka Bouken Nikki
# status code
# 200
# Tanoshii ne
# status code
# 200
# Tanoshii Saki Uta Animation
# status code
# 200
# Tanoshii Sansuu
# status code
# 200
# Tanoshii Sansuu (TV)
# status code
# 200
# Tanoshii Willow Town
# status code
# 200
# Tanpen Animation Junpei Fujita
# status code
# 200
# Tanpen Unico: Kuroi Kumo to Shiroi Hane
# status code
# 200
# Tansa Quest!
# status code
# 200
# Tansu Warashi.
# status code
# 200
# Tansui
# status code
# 200
# Tansuo Diqiucun
# status code
# 200
# Tantan Xiao Dongyuan
# status code
# 200
# Tantei Gakuen Q
# status code
# 200
# Tantei Kageki Milky Holmes TD
# status code
# 200
# Tantei Opera Milky Holmes
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Tantei Opera Milky Holmes Dai 2 Maku
# status code
# 200
# Tantei Opera Milky Holmes Movie: Gyakushuu no Milky Holmes
# status code
# 200
# Tantei Opera Milky Holmes: Alternative
# status code
# 200
# Tantei Opera Milky Holmes: Arsene Karei naru Yokubou
# status code
# 200
# Tantei Opera Milky Holmes: Fun Fun Party Night♪ - Ken to Janet no Okurimono
# status code
# 200
# Tantei Opera Milky Holmes: Psycho no Aisatsu
# status code
# 200
# Tantei Opera Milky Holmes: Summer Special
# status code
# 200
# Tantei Shounen Kageman
# status code
# 200
# Tantei Team KZ Jiken Note
# status code
# 200
# Tantei wa Mou, Shindeiru.
# status code
# 200
# Tantei wa Mou, Shindeiru. Mini Anime
# first
# 251
# last
# 300
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# sleeping
# status code
# 200
# Tantei wa Mou, Shindeiru. Season 2
# status code
# 200
# Tanu no Magical Holiday
# status code
# 200
# Tanuki to Kitsune
# status code
# 200
# Tanuki to Kitsune Specials
# status code
# 200
# Tanuki to Kitsune: Dai 5-kan Hatsubai Kinen Animation
# status code
# 200
# Tanuki-san Ooatari
# status code
# 200
# Nameeeeeeeeeee:
# Tanukichi no Ohanashi
# url
# https://myanimelist.net/anime/35490/Tanukichi_no_Ohanashi
# [<h1 class="title-name h1_bold_none"><strong>Tanukichi no Ohanashi</strong></h1>]
# Tanukichi no Ohanashi
# status code
# 200
# Tao Donghua Pian
# status code
# 200
# Tao Hua Yuan Ji
# status code
# 200
# Tao Qi De Jin Si Hou
# status code
# 200
# Tao Wa Yuan Ji
# status code
# 200
# Taoleujima Beoseuteo
# status code
# 200
# Taoleujima Beoseuteo: Beullaeg-Eosseolteuui Gwihwan
# status code
# 200
# Taoqi Bao Ma Xiao Tiao
# status code
# 200
# Taoqi Bao Ma Xiao Tiao (Movie)
# status code
# 200
# Taoqi Huaxue
# status code
# 200
# Taoqi Maomao Wang
# status code
# 200
# Taoqi Xing Mao
# status code
# 200
# Taoqi Xing Mao 2nd Season
# status code
# 200
# TaoTao Ehonkan Sekai Doubutsu Banashi
# status code
# 200
# Tape
# status code
# 200
# Tapuri Card x Kaijuu Sakaba Kanpai: Kanegon no Shuchou
# status code
# 200
# Tarareba
# status code
# 200
# Tarepanda
# status code
# 200
# Tari Tari
# status code
# 200
# Tari Tari: Kumottari, Kagayaitari, Mata Itsuka Utattari
# status code
# 200
# Tarinai
# status code
# 200
# Tarou no Banpei Senkoutei no Maki
# status code
# 200
# Tarou no Odekake
# status code
# 200
# Tarou no Tomodachi
# status code
# 200
# Tarou wa Mizu ni Naritakatta
# status code
# 200
# Tarou-san no Kisha
# status code
# 200
# Tarzan
# status code
# 200
# Tasogare Otome x Amnesia
# status code
# 200
# Tasogare Otome x Amnesia: Taima Otome
# status code
# 200
# Tasogare Out Focus
# status code
# 200
# Tasukeai no Rekishi: Seimei Hoken no Hajimari
# status code
# 200
# status code
# 429
# Tasuuketsu: Judgement Assizes
# status code
# 200
# Tat-chan - Momo-chan no Fushigina Taiken
# status code
# 200
# Tata He Gaga
# status code
# 200
# Tata Tu Ran Xiang Dao
# status code
# 200
# Tata Tu Ran Xiang Dao 2
# status code
# 200
# Tatakae! Chou Robot Seimeitai Transformers Victory
# status code
# 200
# Tatakae! Chou Robot Seimeitai Transformers Victory Soushuuhen
# status code
# 200
# Tatakae! Dokan-kun: Gekitou-kun
# status code
# 200
# Tatakae! Dokan-kun: Robolympic-hen
# status code
# 200
# Tatakae! Osper
# status code
# 200
# Tatakae!! Iczer-1
# status code
# 200
# Tatakae!! Ramenman
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Tatakae!! Ramenman (Movie)
# first
# 301
# last
# 350
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Tatakau Mono-tachi e Ai wo Komete
# status code
# 200
# Tatakau Shisho: The Book of Bantorra
# status code
# 200
# Tatamp
# status code
# 200
# Tate
# status code
# 200
# Tate no Kuni PV
# status code
# 200
# Tate no Yuusha no Nariagari
# status code
# 200
# Tate no Yuusha no Nariagari Season 2
# status code
# 200
# Tate no Yuusha no Nariagari Season 3
# status code
# 200
# Tatehoko Tsubasa
# status code
# 200
# Tatoeba
# status code
# 200
# Tatoeba Last Dungeon Mae no Mura no Shounen ga Joban no Machi de Kurasu Youna Monogatari
# status code
# 200
# Tatsu no Ko Tarou
# status code
# 200
# Tatsunoko Pro x Peeping Life
# status code
# 200
# Tattoon Master
# status code
# 200
# Tawamure Kobako
# status code
# 200
# Tayo-ui Gonglyong Adventure
# status code
# 200
# Tayo-ui Jangnangam Adventure
# status code
# 200
# Tayu Tayu
# status code
# 200
# Tayutama: Kiss on My Deity
# status code
# 200
# Tayutaum
# status code
# 200
# Tayutayu: Pure My Heart
# status code
# 200
# Te Gong Mingxing
# status code
# 200
# Te Ke Dong Ji Pian
# status code
# 200
# Te no Naka no Mahou
# status code
# 200
# Te wo Tsunaide Arukou
# status code
# 200
# Tea Tea Cherry
# status code
# 200
# Tea Tea Cherry Specials
# status code
# 200
# Teach
# status code
# 200
# Teakamamire no Tenshi The Animation
# status code
# 200
# Tearmoon Teikoku Monogatari: Dantoudai kara Hajimaru, Hime no Tensei Gyakuten Story
# status code
# 429
# status code
# 200
# Tearmoon Teikoku Monogatari: Dantoudai kara Hajimaru, Hime no Tensei Gyakuten Story Mini Anime
# status code
# 200
# Tears to Tiara
# status code
# 200
# Tebie Chedui
# status code
# 200
# Tec-chan no Pet
# status code
# 200
# Techno Police 21C
# status code
# 200
# Technology Shamanism
# status code
# 200
# Technoroid: Overmind
# status code
# 200
# Teddy
# status code
# 200
# Teddy Xiong: Wanju Dazhan
# status code
# 200
# Teekyuu
# status code
# 200
# Teekyuu 2
# status code
# 200
# Teekyuu 2 Specials
# status code
# 200
# Teekyuu 3
# status code
# 200
# Teekyuu 3 Specials
# status code
# 200
# Teekyuu 4
# status code
# 429
# status code
# 200
# Teekyuu 4 Specials
# status code
# 200
# Teekyuu 5
# status code
# 200
# Teekyuu 5 Specials
# status code
# 200
# Teekyuu 6
# status code
# 200
# Teekyuu 6 Specials
# first
# 351
# last
# 400
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Teekyuu 7
# status code
# 200
# Teekyuu 7 Specials
# status code
# 200
# Teekyuu 8
# status code
# 200
# Teekyuu 8 Specials
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Teekyuu 9
# status code
# 200
# Teeter
# status code
# 200
# Tegami
# status code
# 200
# Tegami: Haikei Juugo no Kimi e
# status code
# 200
# Tegamibachi
# status code
# 200
# Tegamibachi Gakuen
# status code
# 200
# Tegamibachi Reverse
# status code
# 200
# Tegamibachi: Hikari to Ao no Gensou Yawa
# status code
# 200
# Tegamibachi: Omakebachi
# status code
# 200
# Tegong Huan Ying 2: Conglin Tegong Dui
# status code
# 200
# Tegong Huan Ying: Conglin Mi Ying
# status code
# 200
# Tegong Tu: Shenmi De Wangzhan
# status code
# 200
# Tegong Tu: Xin De Maoxian
# status code
# 200
# Teienu Theater in Kobe Opening
# status code
# 200
# Teiketsu Bolt
# status code
# 200
# Teikou Penguin
# status code
# 200
# Teinenpi Shoujo Heidi
# status code
# 200
# Teinenpi Shoujo Heidi CMs
# status code
# 200
# Teito Monogatari
# status code
# 200
# Teizokurei Daydream
# status code
# 200
# Tejime
# status code
# 200
# Tejina Shi
# status code
# 200
# Tejina-senpai
# status code
# 200
# Teki wa Kaizoku: Neko-tachi no Kyouen
# status code
# 200
# Tekisetsu de Itai
# status code
# 200
# Tekkamen wo Oe: "d'Artagnan Monogatari" yori
# status code
# 200
# Tekken
# status code
# 200
# Tekken Chinmi
# status code
# 200
# Tekken: Blood Vengeance
# status code
# 200
# Tekken: Bloodline
# status code
# 200
# Tekkon Kinkreet
# status code
# 200
# Tekkon Kinkreet Pilot
# status code
# 200
# Tekusuke Monogatari
# status code
# 200
# Tekuteku
# status code
# 200
# Tele◯Potion
# status code
# 200
# Telecaster B-Boy
# status code
# 200
# Teleclub no Himitsu
# status code
# 200
# Telemonster
# status code
# 200
# Telepath
# status code
# 200
# Telepathist IQ Psycho
# status code
# 200
# Telepathy Shoujo Ran
# status code
# 200
# Teleport
# status code
# 200
# Telescope
# status code
# 200
# Television
# status code
# 200
# Tell the Story to You
# status code
# 200
# Tell Your World
# first
# 401
# last
# 450
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# sleeping
# sleeping
# status code
# 200
# status code
# 200
# Template
# status code
# 200
# Temple
# status code
# 200
# Temple Specials
# status code
# 200
# Temple x Kanojo, Okarishimasu
# status code
# 200
# Templex
# status code
# 200
# Ten
# status code
# 200
# Ten Count
# status code
# 200
# Ten Little Gall Force
# status code
# 200
# Ten made Tobaso
# status code
# 200
# Nameeeeeeeeeee:
# Ten ni Yaka Reru: E ni Yoru Shougen
# url
# https://myanimelist.net/anime/33822/Ten_ni_Yaka_Reru__E_ni_Yoru_Shougen
# [<h1 class="title-name h1_bold_none"><strong>Ten ni Yaka Reru: E ni Yoru Shougen</strong></h1>]
# Ten ni Yaka Reru: E ni Yoru Shougen
# status code
# 200
# Ten no Kawa
# status code
# 200
# Tenamonya Voyagers
# status code
# 200
# Tenbatsu Angel Rabbie☆
# status code
# 200
# Tenchi Muyou!
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Tenchi Muyou! GXP
# status code
# 200
# Tenchi Muyou! GXP: Paradise Shidou-hen
# status code
# 200
# Tenchi Muyou! in Love
# status code
# 200
# Tenchi Muyou! in Love 2: Harukanaru Omoi
# status code
# 200
# Tenchi Muyou! Manatsu no Eve
# status code
# 200
# Tenchi Muyou! Ryououki
# status code
# 200
# Tenchi Muyou! Ryououki 2nd Season
# status code
# 200
# Tenchi Muyou! Ryououki 2nd Season Picture Drama
# status code
# 200
# Tenchi Muyou! Ryououki 3rd Season
# status code
# 200
# Tenchi Muyou! Ryououki 3rd Season Picture Drama
# status code
# 200
# Tenchi Muyou! Ryououki 3rd Season: Tenchi Seirou naredo Namitakashi?
# status code
# 200
# Tenchi Muyou! Ryououki 4th Season
# status code
# 200
# Tenchi Muyou! Ryououki 5th Season
# status code
# 200
# Tenchi Muyou! Ryououki: Heianmuyo! Picture Drama
# status code
# 200
# Tenchi Muyou! Ryououki: Omatsuri Zenjitsu no Yoru!
# status code
# 200
# Tenchi Muyou!: Galaxy Police Mihoshi Space Adventure
# status code
# 200
# Tenchi Souzou Design-bu
# status code
# 200
# Tenchi Souzou Design-bu: Idea 13
# status code
# 200
# Tenda Todoke
# status code
# 200
# Tengai Makyou: Ziria Oboro-hen
# status code
# 200
# Tengen Toppa Gurren Lagann
# status code
# 200
# Tengen Toppa Gurren Lagann Movie 1: Gurren-hen
# status code
# 200
# Tengen Toppa Gurren Lagann Movie 2: Lagann-hen
# status code
# 200
# Tengen Toppa Gurren Lagann Movie Zenyasai: Viral no Amai Yume
# status code
# 200
# Tengen Toppa Gurren Lagann: Kirameki★Yoko Box - Pieces of Sweet Stars
# status code
# 200
# Tengen Toppa Gurren Lagann: Mitee Mono wa Miteen da!!
# status code
# 200
# Tengen Toppa Gurren Lagann: Ore no Gurren wa Pikka-Pika!!
# status code
# 200
# Tengen Toppa Gurren Lagann: Parallel Works
# status code
# 200
# Tengen Toppa Gurren Lagann: Parallel Works 2
# status code
# 200
# Tengoku
# status code
# 200
# Tengoku Daimakyou
# status code
# 200
# Tengu desu
# status code
# 200
# Tengu Taiji
# status code
# 200
# TeNiOE
# status code
# 200
# Tenioha! 2: Limit Over - Mada Mada Ippai, Ecchi Shiyo? The Animation
# status code
# 200
# Tenioha! 2: Nee, Motto Ecchi na Koto Ippai Shiyo? The Animation
# first
# 451
# last
# 500
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Tenioha!: Onnanoko datte Honto wa Ecchi da yo?
# status code
# 200
# Tenjin
# status code
# 200
# Tenjou Tenge
# status code
# 200
# Tenjou Tenge: The Past Chapter
# status code
# 200
# Tenjou Tenge: The Ultimate Fight
# status code
# 200
# Tenjoubito to Akutobito Saigo no Tatakai
# status code
# 200
# Tenjouhen: Utsunomiko
# status code
# 200
# Tenka Hyakken: Meiji-kan e Youkoso!
# status code
# 200
# Tenka Muteki no Gouyaaman★
# status code
# 200
# Tenka Touitsu Koi no Ran: Shutsujin! Saika 4-nin Shuu
# status code
# 200
# Tenka wo Mezashita Sannin no Bushou
# status code
# 200
# Tenkai Knights
# status code
# 200
# Tenki ni Naare
# status code
# 200
# Tenki no Ko
# status code
# 200
# Tenki no Ko CMs
# status code
# 200
# Tenkou Kotofumi
# status code
# 200
# Tenkou-saki no Seiso Karen na Bishoujo ga, Mukashi Danshi to Omotte Issho ni Asonda Osananajimi Datta Ken
# status code
# 200
# Tenkousei
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Tenkousei wa Kounin Kaikeishi!
# status code
# 200
# Tenkousei wa Uchuujin
# status code
# 200
# Tenkuu Danzai Skelter+Heaven
# status code
# 200
# Tenkuu no Escaflowne
# status code
# 200
# Tenkuu no Escaflowne Recaps
# status code
# 200
# Tenkuu no Shiro Laputa
# status code
# 200
# Tenkuu Senki Shurato
# status code
# 200
# Tenkuu Senki Shurato Recaps
# status code
# 200
# Tenkuu Senki Shurato: Sousei e no Anto
# status code
# 200
# Tenkuu Shinpan
# status code
# 200
# Tenkyuu no Arculs
# status code
# 200
# Tenkyuu, Suisei wa Yoru wo Mataide
# status code
# 200
# Tenma no Torayan
# status code
# 200
# Tennen Koi-iro Alcohol
# status code
# 200
# Tennis no Oujisama
# status code
# 200
# Tennis no Oujisama Movie 1: Futari no Samurai - The First Game
# status code
# 200
# Tennis no Oujisama Movie 2: Eikokushiki Teikyuu Shiro Kessen!
# status code
# 200
# Tennis no Oujisama: Another Story - Kako to Mirai no Message
# status code
# 200
# Tennis no Oujisama: Another Story - Kako to Mirai no Message Specials
# status code
# 200
# Tennis no Oujisama: Another Story II - Ano Toki no Bokura
# status code
# 200
# Tennis no Oujisama: Another Story II - Ano Toki no Bokura Specials
# status code
# 200
# Tennis no Oujisama: Atobe kara no Okurimono - Kimi ni Sasageru Tennis Prince Matsuri
# status code
# 200
# Tennis no Oujisama: Best Games!!
# status code
# 200
# Tennis no Oujisama: Message in a Bottle
# status code
# 200
# Tennis no Oujisama: Mini Theater
# status code
# 200
# Tennis no Oujisama: Oshougatsu Special
# status code
# 200
# Tennis no Oujisama: Pair Prince
# status code
# 200
# Tennis no Oujisama: Sonzoku Yama no Hi
# status code
# 200
# Tennis no Oujisama: The Band of Princes Film Kick the Future
# status code
# 200
# Tennis no Oujisama: Zenkoku Taikai-hen
# status code
# 200
# Tennis no Oujisama: Zenkoku Taikai-hen - Final
# status code
# 200
# Tennis no Oujisama: Zenkoku Taikai-hen - Semifinal
# first
# 501
# last
# 550
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Tenpou Ibun: Ayakashi Ayashi
# status code
# 200
# Tenpou Ibun: Ayakashi Ayashi - Ayashi Shinkyoku
# status code
# 200
# Tenpou Suikoden Neo
# status code
# 200
# Tenrankai de Atta Onnanoko
# status code
# 200
# Tenrankai no E
# status code
# 200
# Tensai Bakabon
# status code
# 200
# Tensai Bakabon Pilot
# status code
# 200
# Tensai Bakavon: Yomigaeru Flanders no Inu
# status code
# 200
# Tensai Banpaku Opening
# status code
# 200
# Tensai Eri-chan Kingyo wo Tabeta
# status code
# 200
# Tensai Ouji no Akaji Kokka Saisei Jutsu
# status code
# 200
# Tensai Ouji no Akaji Kokka Saisei Jutsu: Short Drama
# status code
# 200
# Tensai Ouji no Akaji Kokka Saisei Jutsu: Short Drama Specials
# status code
# 200
# Tensai? Dr. Hamax
# status code
# 200
# Tensei Kendo no Harem Colosseo
# status code
# 200
# Tensei Kenja no Isekai Life: Dai-2 no Shokugyou wo Ete, Sekai Saikyou ni Narimashita
# status code
# 200
# Tensei Kizoku no Isekai Boukenroku: Jichou wo Shiranai Kamigami no Shito
# status code
# 200
# Tensei Kizoku, Kantei Skill de Nariagaru
# status code
# 200
# Tensei Mae no Ryouma to Tabuchi
# status code
# 200
# Tensei Oujo to Tensai Reijou no Mahou Kakumei
# status code
# 200
# Tensei Ringo
# status code
# 200
# Tensei shitara Dainana Ouji Datta node, Kimama ni Majutsu wo Kiwamemasu
# status code
# 200
# Tensei shitara Ken deshita
# status code
# 200
# Tensei shitara Ken deshita 2
# status code
# 200
# Tensei shitara Slime Datta Ken
# status code
# 200
# Tensei shitara Slime Datta Ken 2nd Season
# status code
# 200
# Tensei shitara Slime Datta Ken 2nd Season Part 2
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Tensei shitara Slime Datta Ken 2nd Season: Kanwa - Veldora Nikki 2
# status code
# 200
# Tensei shitara Slime Datta Ken 3rd Season
# status code
# 200
# Tensei shitara Slime Datta Ken Movie: Guren no Kizuna-hen
# status code
# 200
# Tensei shitara Slime Datta Ken OVA
# status code
# 200
# Tensei shitara Slime Datta Ken: Coleus no Yume
# status code
# 200
# Tensei shitara Slime Datta Ken: Kanwa - Hinata Sakaguchi
# status code
# 200
# Tensei shitara Slime Datta Ken: Kanwa - Veldora Nikki
# status code
# 200
# Tenshi Kinryouku
# status code
# 200
# Tenshi na Konamaiki
# status code
# 200
# Tenshi na Konamaiki Specials
# status code
# 200
# Tenshi Nanka ja Nai
# status code
# 200
# Tenshi ni Narumon!
# status code
# 200
# Tenshi no 3P!
# status code
# 200
# Tenshi no Agape
# status code
# 200
# Tenshi no Drop
# status code
# 200
# Tenshi no Habataki Jun
# status code
# 200
# Tenshi no Pants
# status code
# 200
# Tenshi no Shippo Chu!
# status code
# 200
# Tenshi no Shippo Chu!: Tenshi no Utagoe
# status code
# 200
# Tenshi no Tamago
# status code
# 200
# Tensura Nikki: Tensei shitara Slime Datta Ken
# status code
# 200
# Tentacle and Witches
# status code
# 200
# Tentai Fu
# first
# 551
# last
# 600
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# sleeping
# status code
# 200
# Tentai Kansoku
# status code
# 200
# Tentai Senshi Sunred
# status code
# 200
# Tentai Senshi Sunred 2nd Season
# status code
# 200
# Tentai Senshi Sunred: Short Corner
# status code
# 200
# Tentoumushi no Otomurai
# status code
# 200
# Tentoumushi no Uta
# status code
# 200
# Tenuto
# status code
# 200
# Teo the Magic Planet Pilot
# status code
# 200
# Teosbatbu Sageonilji PV
# status code
# 200
# Teppen
# status code
# 200
# Teppen!!!!!!!!!!!!!!!
# status code
# 200
# Terada Mokei × Pocari Sweat
# status code
# 200
# Terajima-chou Kidan: Ginnagashi
# status code
# 200
# Terra e...
# status code
# 200
# Terra e... (TV)
# status code
# 200
# Terra e... (TV) Specials
# status code
# 200
# Terra Formars
# status code
# 200
# Terra Formars: Bugs 2-hen
# status code
# 200
# Terra Formars: Earth-hen
# status code
# 200
# Terra Formars: Revenge
# status code
# 200
# Terra Story
# status code
# 200
# Terrace House x Craft Boss
# status code
# 200
# Terrarium Adventure
# status code
# 200
# Teruteru Bouzu wa Osamurai
# status code
# 200
# Tesagure! Bukatsumono
# status code
# 200
# Tesagure! Bukatsumono Encore
# status code
# 200
# Tesagure! Bukatsumono Spin-off Purupurun Sharumu to Asobou
# status code
# 200
# Tesapuru da yo! Schedule no Au Hito dake Shuugou!
# status code
# 200
# Tesla Note
# status code
# 200
# Tesla Note: Mickey to Oliver no Agent Yousei Kouza
# status code
# 200
# TeTeTe! Tomatte!
# status code
# 200
# Tetopettenson
# status code
# 200
# Tetopettenson (2009)
# status code
# 200
# Tetsu no Ko Kanahiru
# status code
# 200
# Tetsugaku Suru Mantohihi
# status code
# 200
# Tetsujin 28-gou
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Tetsujin 28-gou (1980)
# status code
# 200
# Tetsujin 28-gou (2004)
# status code
# 200
# Tetsujin 28-gou Gao!
# status code
# 200
# Tetsujin 28-gou: Hakuchuu no Zangetsu
# status code
# 200
# Tetsujin 28-gou: Tanjou-hen
# status code
# 200
# Tetsuko no Tabi
# status code
# 200
# Tetsuro no Kanata
# status code
# 200
# Tetsuwan Atom
# status code
# 200
# Tetsuwan Atom (1980)
# status code
# 200
# Tetsuwan Atom no Koutsuu Anzen
# status code
# 200
# Tetsuwan Atom to Sagurou! Dosei wo Mawaru Shinpi no Hoshi Titan
# status code
# 200
# Tetsuwan Atom: Ao Kishi no Kan
# status code
# 200
# Tetsuwan Atom: Atom Tanjou no Himitsu
# status code
# 429
# status code
# 200
# Tetsuwan Atom: Chikyuu Saigo no Hi
# first
# 601
# last
# 650
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Tetsuwan Atom: Ivan no Wakusei - Robot to Ningen no Yuujou
# status code
# 200
# Tetsuwan Atom: Kagayakeru Hoshi - Anata wa Aoku, Utsukushii...
# status code
# 200
# Tetsuwan Atom: Uchuu no Yuusha
# status code
# 200
# Tetsuwan Birdy
# status code
# 200
# Tetsuwan Birdy Decode
# status code
# 200
# Tetsuwan Birdy Decode: The Cipher
# status code
# 200
# Tetsuwan Birdy Decode:02
# status code
# 200
# Tettou
# status code
# 200
# Texhnolyze
# status code
# 200
# Texhnolyze: Revisit
# status code
# 200
# Tezuka Chara Ugokashite Mimashita
# status code
# 200
# Tezuka Osamu ga Kieta?! 20-seiki Saigo no Kaijiken
# status code
# 200
# Tezuka Osamu Monogatari
# status code
# 200
# Tezuka Osamu Monogatari: Boku wa Son Gokuu
# status code
# 200
# Tezuka Osamu no Buddha: Akai Sabaku yo! Utsukushiku
# status code
# 200
# Tezuka Osamu no Buddha: Owarinaki Tabi
# status code
# 200
# Tezuka Osamu no Don Dracula
# status code
# 200
# Tezuka Osamu no Kyuuyaku Seisho Monogatari: In the Beginning
# status code
# 200
# Nameeeeeeeeeee:
# Tezuka Osamu no Uchuu Wonder 3: Ginga Renmei no Shisha
# url
# https://myanimelist.net/anime/39359/Tezuka_Osamu_no_Uchuu_Wonder_3__Ginga_Renmei_no_Shisha
# [<h1 class="title-name h1_bold_none"><strong>Tezuka Osamu no Uchuu Wonder 3: Ginga Renmei no Shisha</strong></h1>]
# Tezuka Osamu no Uchuu Wonder 3: Ginga Renmei no Shisha
# status code
# 200
# Thank You Dropkick!
# status code
# 200
# That Is How I Roll!
# status code
# 200
# That's Hanakappa Musical: Pan to Gohan, Docchi nano!?
# status code
# 200
# The 3 Meisama Anime wa Anime de Arissho!
# status code
# 200
# The Adventures of Hello Kitty & Friends
# status code
# 200
# The Angler
# status code
# 200
# The Animatrix
# status code
# 200
# The Arari Show
# status code
# 200
# The Aurora: Umi no Aurora
# status code
# 200
# The Baby Birds of Norman McLaren
# status code
# 200
# The Bathroom
# status code
# 200
# The Big O
# status code
# 200
# The Borgman: Last Battle
# status code
# 200
# The Button
# status code
# 200
# The Chocolate Panic Picture Show
# status code
# 200
# The Circle Of Butterflies
# status code
# 200
# The Closet
# status code
# 200
# The Cockpit
# status code
# 200
# The Collected Animations of ICAF (2001-2006)
# status code
# 200
# The Concubine Contract PV
# status code
# 200
# The Crater
# status code
# 200
# The Curlydog Story
# status code
# 200
# The Cutest Boy Band in the World
# status code
# 200
# The Dawn of Ape
# status code
# 200
# The Dentsu Advertising Awards: Walk Walk
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# The Disappearance of Conan Edogawa: The Worst Two Days in History
# status code
# 200
# The Embryo Develops into a Fetus
# status code
# 200
# The End
# status code
# 200
# The Epic Of ZektBach
# status code
# 200
# The Epic of Zektbach: Ristaccia
# status code
# 200
# The Everlasting Guilty Crown
# first
# 651
# last
# 700
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# The Fable
# status code
# 200
# The Finest
# status code
# 200
# The First Slam Dunk
# status code
# 200
# The Five Killers
# status code
# 200
# the FLY BanD!
# status code
# 200
# The Forgotten Princess Just Wants Peace
# status code
# 200
# The Four Seasons
# status code
# 429
# status code
# 200
# The Fullmoon Tradition: Indra Pilot Film
# status code
# 200
# The Gakuen Choujo-tai
# status code
# 200
# The Ghost of Cartoon
# status code
# 200
# The Gift
# status code
# 200
# The God of High School
# status code
# 200
# The God of High School PV
# status code
# 200
# The Green Wind
# status code
# 200
# The Gregory Gallery Tour Special
# status code
# 200
# The Grown Dinosaur
# status code
# 200
# The Guts!
# status code
# 200
# The Hakkenden
# status code
# 200
# The Hakkenden: Shin Shou
# status code
# 200
# The Harmonic Gleam Vibration
# status code
# 200
# The House of Greed
# status code
# 200
# status code
# 429
# The Humanoid: Ai no Wakusei Lezeria
# status code
# 200
# The iDOLM@STER
# status code
# 200
# The iDOLM@STER Cinderella Girls
# status code
# 200
# The iDOLM@STER Cinderella Girls 2-shuunen Kinen PV
# status code
# 200
# The iDOLM@STER Cinderella Girls 2nd Season
# status code
# 200
# The iDOLM@STER Cinderella Girls: 5th Live Tour Serendipity Parade!!! Manner Movie
# status code
# 200
# The iDOLM@STER Cinderella Girls: Anytime, Anywhere with Cinderella.
# status code
# 200
# The iDOLM@STER Cinderella Girls: Special Program
# status code
# 200
# The iDOLM@STER Cinderella Girls: Spin-off!
# status code
# 200
# The iDOLM@STER Cinderella Girls: Starlight Stage - 5-shuunen Kinen "Go Just Go!" PV
# status code
# 200
# THE iDOLM@STER Cinderella Girls: Starlight Stage - Shinshun! Happy New Year Campaign
# status code
# 200
# The IDOLM@STER Cinderella Girls: Starlight Stage CMs
# status code
# 200
# The iDOLM@STER Cinderella Girls: U149
# status code
# 200
# The iDOLM@STER Cinderella Girls: U149 Recap
# status code
# 200
# The iDOLM@STER Cinderella Girls: U149 Special
# status code
# 200
# The iDOLM@STER Live For You!
# status code
# 200
# The iDOLM@STER Million Live!
# status code
# 200
# The iDOLM@STER Million Live! "Dreaming!" Animation PV
# status code
# 200
# The iDOLM@STER Million Live! 1-shuunen Kinen PV
# status code
# 200
# The iDOLM@STER Million Live! 4-shuunen Kinen PV
# status code
# 200
# The iDOLM@STER Movie: Kagayaki no Mukougawa e!
# status code
# 200
# The iDOLM@STER Prologue SideM: Episode of Jupiter
# status code
# 200
# The iDOLM@STER Shiny Colors
# status code
# 200
# The iDOLM@STER Shiny Festa
# status code
# 200
# The iDOLM@STER SideM
# status code
# 200
# The iDOLM@STER SideM: 315 Variety Pack! Made In Passion!
# status code
# 200
# The iDOLM@STER SideM: Wake Atte Mini!
# status code
# 200
# The iDOLM@STER SideM: Wake Atte Mini! - Shoshi Kantetsu Daisouji!
# status code
# 200
# The iDOLM@STER SideM: Wake Atte Mini! Specials
# first
# 701
# last
# 750
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# sleeping
# sleeping
# status code
# 429
# sleeping
# status code
# 200
# status code
# 200
# The iDOLM@STER: 765 Pro to Iu Monogatari
# status code
# 200
# The Impression of First Gundam
# status code
# 200
# The Kabocha Wine
# status code
# 200
# status code
# 429
# The Kabocha Wine: Nita no Aijou Monogatari
# status code
# 200
# The Kabocha Wine: Ore to Aitsu no Shinkon Ryokou!?
# status code
# 200
# The King of Fighters XV
# status code
# 200
# The King of Fighters: Destiny
# status code
# 200
# The Lamp Man
# status code
# 200
# The Last Bullet
# status code
# 200
# The Last: Naruto the Movie
# status code
# 200
# The Legend of Heroes: Sen no Kiseki - Northern War
# status code
# 200
# The Legend of Huainanzi
# status code
# 200
# The Legend of Huainanzi 2nd Season
# status code
# 200
# The Marginal Service
# status code
# 200
# The Marshmallow Times
# status code
# 200
# The Midnight★Animal
# status code
# 200
# The Miracle
# status code
# 200
# The Missing 8
# status code
# 200
# The Mob
# status code
# 200
# The Movement
# status code
# 200
# The Naked King
# status code
# 200
# The New A-Class.: Next Stage with YOU
# status code
# 200
# The New Hazzys
# status code
# 200
# The North Face Japan CMs
# status code
# 200
# The Peak
# status code
# 200
# The Perfect World
# status code
# 200
# The Place Where We Were
# status code
# 200
# The Planet of Stray Cats
# status code
# 200
# THE POLiCY
# status code
# 429
# status code
# 200
# The Primitives: Bongo and Grunge
# status code
# 200
# The Rapeman
# status code
# 200
# The Reflection
# status code
# 200
# The Samurai
# status code
# 200
# The Satisfaction
# status code
# 200
# The Siamese: First Mission
# status code
# 200
# The Sky Crawlers
# status code
# 200
# The Snack World
# status code
# 200
# The Snack World (TV)
# status code
# 200
# The Snack World: Hitogirai no Renny
# status code
# 200
# The SoulTaker: Tamashii-gari
# status code
# 200
# The SoulTaker: Tamashii-gari - Komugi Daisakusen
# status code
# 200
# The Starry Night
# status code
# 200
# The Sukkiri Crawlers
# status code
# 200
# The Sun Sank
# status code
# 429
# status code
# 200
# The Supergal
# status code
# 200
# The Tales of Rien Village #1: "Toilet ni Ittokiya"
# status code
# 200
# The Third Eye
# status code
# 200
# The Third: Aoi Hitomi no Shoujo
# status code
# 200
# The TV Show
# status code
# 200
# The Urotsuki
# first
# 751
# last
# 800
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# The World of Golden Eggs
# status code
# 200
# The☆Doraemons: Dokidoki Kikansha Daibakusou!
# status code
# 200
# The☆Doraemons: Goal! Goal! Goal!!
# status code
# 200
# The☆Doraemons: Mushimushi Pyonpyon Daisakusen!
# status code
# 200
# The☆Doraemons: Mystery X'Mass Daisakusen
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# The☆Doraemons: Strange, Sweets, Strange?
# status code
# 200
# The☆Doraemons: The Mysterious Thief Dorapan The Mysterious Cartel
# status code
# 200
# The☆Ultraman
# status code
# 200
# The★Fire G-Men
# status code
# 200
# Therapy
# status code
# 200
# There She Is!!
# status code
# 200
# Thermae Romae
# status code
# 200
# Thermae Romae Novae
# status code
# 200
# Thermae Romae Specials
# status code
# 200
# Thermae Romae x Asahi Shimbun Digital Collaboration
# status code
# 200
# Thermae Romae x LOFT Collaboration
# status code
# 200
# Thermae Romae x Rêveur Collaboration
# status code
# 200
# Thermae Romae x TOTO Collaboration
# status code
# 200
# Thermae Romae x Yoyogi Animation Gakuin Collaboration
# status code
# 200
# Thermae Romae: Kodai Romajin ga Uchuu e
# status code
# 200
# This Is My House
# status code
# 200
# This Is Not Blue
# status code
# 200
# Three Workers
# status code
# 200
# Through the Windows
# status code
# 200
# Thunder
# status code
# 200
# Tian Bao Fuyao Lu
# status code
# 200
# Tian Bao Fuyao Lu 2nd Season
# status code
# 200
# Tian Bao Fuyao Lu 3rd Season
# status code
# 200
# Tian Cai Za Ji Yan Yuan
# status code
# 200
# Tian Guan Cifu
# status code
# 200
# Tian Guan Cifu Er
# status code
# 200
# Tian Guan Cifu Special
# status code
# 200
# Tian Huang Zhan Shen
# status code
# 200
# Tian Jiang Xiaozi
# status code
# 200
# Tian Lang Zhan Ji
# status code
# 200
# Tian Mei De Yao Hen
# status code
# 200
# Tian Qi Ri
# status code
# 200
# Tian Shu Qi Tan
# status code
# 200
# Tian Tian Hao Haizi
# status code
# 200
# Tian Tian Hao Xiguan
# status code
# 200
# Tian Tian Quan Baobei: Feixing Leyuan
# status code
# 200
# Tian Tian Quan Baobei: Gongfu Xueyuan
# status code
# 200
# Tian Tian Quan Baobei: Mifeng Huayuan
# status code
# 200
# Tian Tian Quan Baobei: Saiche Xiao Zhen
# status code
# 200
# Tian Xin Ge Ge
# status code
# 200
# Tian Xin Ge Ge 2nd Season
# status code
# 200
# Tian Xin Ge Ge 3rd Season
# status code
# 200
# Tian Xin Ge Ge 4th Season
# status code
# 200
# Tian Xin Ge Ge 5th Season
# status code
# 200
# Tian Xin Ge Ge: Henian Duanpian
# first
# 801
# last
# 850
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Tian Xin Ge Ge: Huanbao Xilie
# status code
# 200
# Tian Yan Chuanqi
# status code
# 200
# status code
# 429
# Tian Yanshen Hu
# status code
# 200
# Tian Yanshen Niu
# status code
# 200
# Tian Yanshen Tu
# status code
# 200
# Tian Yi Que
# status code
# 200
# Tian You Fan Tong
# status code
# 200
# Tian Yu
# status code
# 200
# Tian Yu 2nd Season: Cang Gu Zhi Ban
# status code
# 200
# Tian Zhen Yu Kung Fu Wa
# status code
# 200
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 429
# Tiancai Faming Jia
# status code
# 200
# Tiancai Lianmeng
# status code
# 200
# Tianchi Shuiguai
# status code
# 200
# Tianmi Tegong Dui
# status code
# 200
# Tianshang Diao Xia Ge Zhubajie
# status code
# 200
# Tiantian Chengzhang Ji
# status code
# 200
# Tiantian Chengzhang Ji 2nd Season
# status code
# 200
# Tiantian Chengzhang Ji 3rd Season
# status code
# 200
# Tiantian Chengzhang Ji 4th Season
# status code
# 200
# Tiantian Jiayuan
# status code
# 200
# Tiantian Kuaile
# status code
# 200
# Tiantian Xiao
# status code
# 200
# Tianwai Fuxing: Chi Jian Chuanqi
# status code
# 200
# Tianyan Guilai
# status code
# 200
# Tianyan Xiao Shentong
# status code
# 200
# Tianyan You Qi Zhao
# status code
# 200
# Tianyan Zhi Zhan
# status code
# 200
# Tianyuan Xiao Jingling
# status code
# 200
# Tiaowei Gongyu
# status code
# 200
# Tiaowei Gongyu: Xiao Shenghuo Da Daoli
# status code
# 200
# Tiaoyue Zhanshi
# status code
# 200
# Tiaoyue Zhanshi 2
# status code
# 200
# Tiaoyue Zhanshi Fanwai Pian
# status code
# 200
# Tibet Inu Monogatari
# status code
# 200
# Tic Tac Dreamin'
# status code
# 200
# Tick & Tack
# status code
# 200
# Tick Tock
# status code
# 200
# Tico Chunji Pian
# status code
# 200
# Tico Dongji Pian
# status code
# 200
# Tico Jiang Gushi
# status code
# 200
# Tico Xiaji Pian
# status code
# 200
# Tico: Shuqi de Weiji
# status code
# 200
# Ticonderonga no Iru Umi
# status code
# 200
# Tide-Line Blue
# status code
# 200
# Tide-Line Blue: Kyoudai
# status code
# 200
# Tie Shan Gongzhu
# status code
# 200
# Tiejia Wei Chong Zhi Qi Ren Wang
# status code
# 200
# Tiexue Yang Jia Jiang
# status code
# 200
# Tiger & Bunny
# status code
# 200
# Tiger & Bunny 2
# first
# 851
# last
# 900
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# sleeping
# status code
# 200
# Tiger & Bunny 2 Part 2
# status code
# 200
# Tiger & Bunny Movie 1: The Beginning
# status code
# 200
# Tiger & Bunny Movie 2: The Rising
# status code
# 200
# Tiger & Bunny Pilot
# status code
# 200
# Tiger & Bunny Recaps
# status code
# 200
# Tiger & Bunny: Too Many Cooks Spoil the Broth.
# status code
# 200
# Tiger Mask
# status code
# 200
# Tiger Mask (Movie)
# status code
# 200
# Tiger Mask Fuku Men League Sen
# status code
# 200
# Tiger Mask Nisei
# status code
# 200
# Tiger Mask Pilot Film
# status code
# 200
# Tiger Mask W
# status code
# 200
# Tight-rope
# status code
# 200
# Timbre A to Z
# status code
# 200
# Time
# status code
# 200
# Time Bokan
# status code
# 200
# Time Bokan 2000: Kaitou Kiramekiman
# status code
# 200
# Time Bokan 24
# status code
# 200
# Time Bokan Oudou Fukko
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Time Bokan Series: Gyakuten Ippatsuman
# status code
# 200
# Time Bokan Series: Itadakiman
# status code
# 200
# Time Bokan Series: Time Patroltai Otasukeman
# status code
# 200
# Time Bokan Series: Yatterman
# status code
# 200
# Time Bokan Series: Yattodetaman
# status code
# 200
# Time Bokan Series: Zenderman
# status code
# 200
# Time Bokan: Gyakushuu no San Akunin
# status code
# 200
# Time Driver: Bokura ga Kaita Mirai
# status code
# 200
# Time for Christmas
# status code
# 200
# Time Gram
# status code
# 200
# Time Machine
# status code
# 200
# Time on the Planet
# status code
# 200
# Time Ranger Cesar Boy no Bouken: Roma Teikoku-hen
# status code
# 200
# Time Slip 1923: Mori no Miracle Jishin Taiken
# status code
# 200
# Time Slip Ichimannen: Prime Rose
# status code
# 200
# Time Slip Shima Kousaku
# status code
# 200
# Time Travel Shoujo: Mari Waka to 8-nin no Kagakusha-tachi
# status code
# 200
# Time Travel Tondekeman!
# status code
# 200
# Time Trip wa Ginza nite
# status code
# 200
# Time-Patrol Bon: Fujiko F. Fujio Anime Special - SF Adventure
# status code
# 200
# Time: Toki no Shiori
# status code
# 200
# Timeless
# status code
# 200
# Timeless Tree
# status code
# 200
# Timing
# status code
# 200
# Timing (Movie)
# status code
# 200
# Tinderbox
# status code
# 200
# Ting Ting Zhishi Chengbao Lixian Ji
# status code
# 200
# Tiny Evil
# status code
# 200
# Tire Kan x Kamiusagi Rope
# status code
# 200
# Tirori Mix
# status code
# 200
# Tistou Midori no Oyayubi
# first
# 901
# last
# 950
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Titanium 2 Step feat. Sal Principato
# status code
# 200
# Titi He Kiki: Moli Ketang
# status code
# 200
# Titipo Titipo
# status code
# 200
# status code
# 429
# Titipo Titipo 2
# status code
# 200
# Titipo Titipo 3
# status code
# 200
# Title Idol
# status code
# 200
# TO
# status code
# 200
# To Be Hero
# status code
# 200
# To Be Me
# status code
# 200
# To Dimension
# status code
# 200
# To Disappear
# status code
# 200
# To Heart
# status code
# 200
# To Heart 2
# status code
# 200
# To Heart 2 AD
# status code
# 429
# status code
# 200
# To Heart 2 AD Plus
# status code
# 200
# To Heart 2 Adnext
# status code
# 200
# To Heart 2 OVA
# status code
# 200
# To Heart 2 Special
# status code
# 200
# To Heart 2: Dungeon Travelers
# status code
# 200
# To Heart Omake
# status code
# 200
# To Heart: Remember My Memories
# status code
# 200
# To Heart: Remember My Memories Specials
# status code
# 200
# status code
# 429
# status code
# 429
# status code
# 429
# To LOVE-Ru
# status code
# 200
# To LOVE-Ru Darkness
# status code
# 200
# To LOVE-Ru Darkness 2nd
# status code
# 200
# To LOVE-Ru Darkness 2nd OVA
# status code
# 200
# To LOVE-Ru Darkness 2nd Specials
# status code
# 200
# To LOVE-Ru Darkness OVA
# status code
# 200
# To LOVE-Ru OVA
# status code
# 200
# To LOVE-Ru: Multiplication - Mae kara Ushiro kara
# status code
# 200
# TO-Y
# status code
# 200
# Toaru Hikuushi e no Koiuta
# status code
# 200
# Toaru Hikuushi e no Tsuioku
# status code
# 200
# Toaru Kagaku no Accelerator
# status code
# 200
# Toaru Kagaku no Accelerator: Tobidase Ippou-san - Hachamecha Kaishingeki
# status code
# 200
# Toaru Kagaku no Railgun
# status code
# 200
# Toaru Kagaku no Railgun S
# status code
# 200
# Toaru Kagaku no Railgun S: Daiji na Koto wa Zenbu Sentou ni Osowatta
# status code
# 200
# Toaru Kagaku no Railgun S: Motto Marutto Railgun
# status code
# 200
# Toaru Kagaku no Railgun T
# status code
# 200
# Toaru Kagaku no Railgun T: Motto Marutto Railgun
# status code
# 200
# Toaru Kagaku no Railgun: Entenka no Satsuei Model mo Raku Ja Arimasen wa ne.
# status code
# 200
# Toaru Kagaku no Railgun: Misaka-san wa Ima Chuumoku no Mato desu kara
# status code
# 200
# Toaru Kagaku no Railgun: Motto Marutto Railgun
# status code
# 200
# Toaru Majutsu no Index
# status code
# 200
# Toaru Majutsu no Index 10-shuunen Kinen PV
# status code
# 200
# Toaru Majutsu no Index II
# status code
# 200
# Toaru Majutsu no Index III
# status code
# 200
# Toaru Majutsu no Index Movie: Endymion no Kiseki
# status code
# 200
# Toaru Majutsu no Index-tan
# first
# 951
# last
# 1000
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Toaru Majutsu no Index-tan II
# status code
# 200
# Toaru Majutsu no Index-tan III
# status code
# 200
# Toaru Majutsu no Index-tan Movie: Endymion no Kiseki - Ga Attari Nakattari
# status code
# 200
# Toaru Ossan no VRMMO Katsudouki
# status code
# 200
# Tobacco Kumo
# status code
# 200
# Tobacco to Hai
# status code
# 200
# Tobacco wa Dasai
# status code
# 200
# Tobe! Isami
# status code
# 200
# Tobe! Kujira no Peek
# status code
# 200
# Tobe! Pegasus Kokoro no Goal ni Shoot
# status code
# 200
# Tobenai Hotaru
# status code
# 200
# Tobidase! Bacchiri
# status code
# 200
# Tobidase! Dokan-kun
# status code
# 200
# Tobidase! Dokan-kun Specials
# status code
# 200
# Tobidase! Machine Hiryuu
# status code
# 200
# Tobidase! Narase! Pui Pui Molcar
# status code
# 200
# Tobidase! To the Cosmic!!
# status code
# 200
# Tobidase!! Buddy-kun
# status code
# 200
# Tobidashi wa Abunaizo! Mushimushi Mura no Koutsuu Anzen
# status code
# 200
# Tobidashicha dame!
# status code
# 200
# ...
# first
# 1051
# last
# 1093
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Z/X: Code Reunion
# status code
# 200
# Z/X: Ignition
# status code
# 200
# Zai Na Yaoyuan Di Difang
# status code
# 200
# Zakuro Yashiki
# status code
# 200
# Zan Sayonara Zetsubou Sensei
# status code
# 200
# Zan Sayonara Zetsubou Sensei Bangaichi
# status code
# 200
# Zang Ling Wangzhixue Yu Jingling
# status code
# 200
# Zanki
# status code
# 200
# Zankyou no Terror
# status code
# 200
# Zanmai
# status code
# 200
# Zannen na Ikimono Jiten
# status code
# 200
# Zannen na Ikimono Jiten (2019)
# status code
# 200
# Zannen na Ikimono Jiten (2021)
# status code
# 200
# Zannen na Ikimono Jiten (2022)
# status code
# 200
# Zannen na Ikimono Jiten (Special)
# status code
# 200
# Zannen na Ikimono Jiten the Movie
# status code
# 200
# Zannen Onna Kanbu Black General-san
# status code
# 200
# Zanting! Rang Wo Cha Gonglue
# status code
# 200
# Zap Cat
# status code
# 200
# Zashiki Warashi no Tatami-chan
# status code
# 200
# Zassou-kun
# status code
# 200
# Zatsu Tabi: That's Journey
# status code
# 200
# Zawazawa
# status code
# 200
# Zdravstvuite!
# status code
# 200
# Ze Tian Ji
# status code
# 200
# Ze Tian Ji 2nd Season
# status code
# 200
# Ze Tian Ji 3rd Season
# status code
# 200
# Ze Tian Ji 4th Season
# status code
# 200
# Ze Tian Ji 5th Season
# status code
# 200
# Zecchou Rocket
# status code
# 200
# Zecchou Sanka
# status code
# 200
# Zegapain
# status code
# 200
# Zegapain ADP
# status code
# 200
# Zegapain: Olta Moda-hen
# status code
# 200
# Zekkyou Gakkyuu
# status code
# 200
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 429
# Zekkyou Gakkyuu: Tensei
# status code
# 200
# Zen-chan Two-chan
# status code
# 200
# Zen: Grogu to Makkuro Kurosuke
# status code
# 200
# Zenbu Wakatteru
# status code
# 200
# Zenchuu Maite
# status code
# 200
# Zenmai Zamurai
# status code
# 200
# Zenmaiji-kake no Truffe
# status code
# 200
# Zeno: Kagirinaki Ai ni
# status code
# 200
# Zenonzard The Animation
# status code
# 200
# Zenonzard The Animation Episode 0
# status code
# 200
# Zenryoku Usagi
# status code
# 200
# Zenryoku Usagi (2023)
# status code
# 200
# Zenryoku Yobikou 5.5 Seminar
# status code
# 200
# Zenryoku Yobikou 5.5 Seminar Prologue
# status code
# 200
# Zentaiteki ni Sensation
# status code
# 200
# Zeonic Front: Kidou Senshi Gundam 0079 - Zeon no Hifun
# status code
# 200
# Zeonic Toyota Special Movie
# status code
# 200
# Zephyr
# status code
# 200
# Zero
# status code
# 200
# Zero Duel Masters
# status code
# 200
# Zero kara Hajimeru Mahou no Sho
# status code
# 200
# Zero no Ashiato
# status code
# 200
# Zero no Mono
# status code
# 200
# Zero no Tsukaima
# status code
# 200
# Zero no Tsukaima F
# status code
# 200
# Zero no Tsukaima: Futatsuki no Kishi
# status code
# 200
# Zero no Tsukaima: Princesses no Rondo
# status code
# 200
# Zero no Tsukaima: Princesses no Rondo - Yuuwaku no Sunahama
# status code
# 200
# Zero no Tsukaima: Princesses no Rondo Picture Drama
# status code
# 200
# Zero Seiki Movie 1: Emeraldas
# status code
# 200
# Zero Seiki Movie 2: Herlock
# status code
# 200
# Zero Seiki Movie 3: Maetel
# status code
# 200
# Zero Sugar Saero CM
# status code
# 200
# Zero Sum Game: Sex Crime
# status code
# 200
# Zero Tester
# status code
# 200
# Zero Tester: Chikyuu wo Mamore!
# status code
# 200
# Zet Ranger
# status code
# 200
# Zetman
# status code
# 200
# Zetsuai 1989
# status code
# 200
# Zetsubou Funsai Shoujo ∞ Amida
# status code
# 200
# Zetsubou no Kaibutsu
# status code
# 200
# Zetsubou-san
# status code
# 200
# Zetsuen no Tempest
# status code
# 200
# Zetsumetsu Kigu Shoujo: Amazing Twins
# status code
# 200
# Zetsumetsu Kigu-shun.
# status code
# 200
# Zetsumetsu Kigu-shun. (2020)
# status code
# 200
# Zettai 15-byou Animation!
# status code
# 200
# Zettai Bouei Leviathan
# status code
# 200
# Zettai Bouei Leviathan: Mini Takibi Gekijou
# status code
# 200
# Zettai Junpaku♡Mahou Shoujo
# status code
# 200
# Zettai Junshu☆Kyousei Kozukuri Kyokashou!!
# status code
# 200
# Zettai Karen Children
# status code
# 200
# Zettai Karen Children OVA: Aitazousei! Ubawareta Mirai?
# status code
# 200
# Zettai Karen Children: Gentei Kaikin!! OVA Chou Sakidori Special!!
# status code
# 200
# Zettai Karen Children: Oobanburumai! Natsuko to Hotaru no B.A.B.E.L. Tsuushin
# status code
# 200
# Zettai Karen Children: The Unlimited - Hyoubu Kyousuke
# status code
# 200
# Zettai Muteki Raijin-Oh
# status code
# 200
# Zettai Muteki Raijin-Oh (1992)
# status code
# 200
# Zettai Shougeki: Platonic Heart
# status code
# 200
# Zettai Shougeki: Platonic Heart Picture Drama
# status code
# 200
# Zettai Shounen
# status code
# 200
# Zettai Yareru Greece Shinwa
# status code
# 200
# Zettai Zetsumei Dangerous Jiisan
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Zettai Zetsumei Dangerous Jiisan (2004)
# status code
# 200
# Zettai Zetsumei Dangerous Jiisan (2005)
# first
# 301
# last
# 400
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Zettai Zetsumei Dangerous Jiisan Special-ban
# status code
# 200
# Zhan Long Si Qu
# status code
# 200
# Zhan Qiannian
# status code
# 200
# Zhan Shou Zhi Ren
# status code
# 200
# Zhan Shuang Panini
# status code
# 200
# Zhandou Ba Ling Shou
# status code
# 200
# Zhandou Wang Zhi Jufeng Zhan Hun
# status code
# 200
# Zhandou Wang Zhi Jufeng Zhan Hun 2
# status code
# 200
# Zhandou Wang Zhi Jufeng Zhan Hun 3
# status code
# 200
# Zhandou Wang Zhi Jufeng Zhan Hun 5
# status code
# 429
# status code
# 200
# Zhandou Wang Zhi Jufeng Zhan Hun 5: Heti Fanwai Pian
# status code
# 200
# Zhandouban Geji!
# status code
# 200
# Zhandouban Geji! 2nd Season
# status code
# 200
# Zhandouban Geji! Season Zero
# status code
# 200
# Zhandouban Geji! Shanyao De Richang
# status code
# 200
# Zhang Fa Mei
# status code
# 200
# Zhang Fei Shen Gua
# status code
# 200
# Zhang Le Tui De Mang Guo
# status code
# 200
# Zhang Xiao He Donghua
# status code
# 200
# Zhang Zai Wu Li De Zhu Sun
# status code
# 200
# Zhangbai Jingling
# status code
# 200
# Zhangda Weiba De Tuzi
# status code
# 200
# Zhanguo Fan
# status code
# 200
# Zhangyu Ge
# status code
# 200
# Zhao Shi Gu Er
# status code
# 200
# Zhao Xiao Ge Ge
# status code
# 200
# Zhe Shi Yi Shou Ge
# status code
# 200
# Zhe Shui Qianqiu
# status code
# 200
# Zhe Tian
# status code
# 200
# Zhege Nianji Huan Neng Dang Daxia Ma
# status code
# 200
# Zhege Nusheng Hen Putong
# status code
# 200
# Zhen Dao Ge
# status code
# 200
# Zhen Dao Ge: Chenshi Hang
# status code
# 200
# Zhen Dao Ge: Tebie Pian
# status code
# 200
# Zhen Gongfu: Aoyun Zai Wojia
# status code
# 200
# Zhen Gyi Hong Shi
# status code
# 200
# Zhen Hai Baowei Zhan
# status code
# 200
# Zhen Hun Jie
# status code
# 200
# Zhen Hun Jie 3rd Season
# status code
# 200
# Zhen Hun Jie: Bei Luo Shi Men Pian Part 1
# status code
# 200
# Zhen Hun Jie: Bei Luo Shi Men Pian Part 2
# status code
# 200
# Zhen Jia Li Kui
# status code
# 200
# Zhen Jia Senlin Wang
# status code
# 200
# Zhen Wu Dianfeng
# status code
# 200
# Zhen Wu Dianfeng 2nd Season
# status code
# 200
# Zhen Yang Wushen
# status code
# 200
# Zhenbao Dang An
# status code
# 200
# Zheng Cheng Gong
# status code
# 200
# Zheng He 1405: Mo Hai Xun Zong
# status code
# 200
# Zheng He Xia Xiyang
# first
# 401
# last
# 450
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# sleeping
# status code
# 200
# Zheng Yi Men
# status code
# 200
# Zheng Zai Jiang Gush: Shi Er Shengxiao
# status code
# 200
# Zhengjing Shao Zhu de Xingfu Shenghuo
# status code
# 200
# Zhengjiu Diqiu, Maiquan Keke Zai Hang Dong
# status code
# 200
# Zhengjiu Zhu Luo Ji
# status code
# 200
# Zhengyi Xiao Tu Jing
# status code
# 200
# Zhengzhi
# status code
# 200
# Zhezhi Zongdongyuan: Zhi Bao Qibing
# status code
# 200
# Zhi Dou Wuya
# status code
# 200
# Zhi Duoduo Qihuan Xingkong Zhi Lu
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Zhi Duoduo Zhi Duoduo
# status code
# 200
# Zhi Duoduo: Jieri Jianianhua
# status code
# 200
# Zhi Pengyou
# status code
# 200
# Zhi Qu Haidi Cheng
# status code
# 200
# Zhi Qu Wei Hu Shan
# status code
# 200
# Zhi Ren Dao Luan Ji
# status code
# 200
# Zhi Ren Guo
# status code
# 200
# Zhi Shanzhi Dao
# status code
# 200
# Zhiduo Xingjimu
# status code
# 200
# Zhihao Beipan Diqiule
# status code
# 200
# Zhihui Dao
# status code
# 200
# Zhihui Mima
# status code
# 200
# Zhihui Senlin
# status code
# 200
# Zhihui Zhi Cheng
# status code
# 200
# Zhihui Zhuangyuan
# status code
# 200
# Zhihui Zidan Che
# status code
# 200
# Zhili Shuxue Da Pengche
# status code
# 200
# Zhiling Baobei
# status code
# 200
# Zhimou Jiazu
# status code
# 200
# Zhiqu Yang Xuetang: Diqiu Jianianhua
# status code
# 200
# Zhiqu Yang Xuetang: Dong Zhi Wu Pian Pian
# status code
# 200
# Zhiqu Yang Xuetang: Qihuan Chengyu Shu
# status code
# 200
# Zhiqu Yang Xuetang: Yangyang Lai Yunbao
# status code
# 200
# Zhiqu Yang Xuetang: Yangyang Qu Maoxian
# status code
# 200
# Zhiqu Yang Xuetang: Yangyang You Shijie
# status code
# 200
# Zhiqu Yang Xuetang: Yundong Pian
# status code
# 200
# Zhishi Laoren
# status code
# 200
# Zhong Hua Xiao Zi
# status code
# 200
# Zhong Li
# status code
# 200
# Zhong Sheng Xiang
# status code
# 200
# Zhong Shu
# status code
# 429
# status code
# 200
# Zhongdian Fuzi
# status code
# 200
# Zhongguo Changshi Ban
# status code
# 200
# Zhongguo Hao Gushi
# status code
# 200
# Zhongguo Huiben Jingdian Mingzhu Xilie: Shouhui Sanguo
# status code
# 200
# Zhongguo Huiben Jingdian Mingzhu Xilie: Shouhui Shuihu
# status code
# 200
# Zhongguo Huiben Jingdian Mingzhu Xilie: Shouhui Xiyou
# status code
# 200
# Zhongguo Jingqi Xiansheng
# status code
# 200
# Zhongguo Minsu Gushi
# status code
# 200
# Zhongguo Nanhai: Hong Zhanhui
# first
# 451
# last
# 500
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Zhongguo Qi Tan
# status code
# 200
# Zhongguo Qiao Guniang: Huangdao Po
# status code
# 200
# status code
# 429
# Zhongguo Xiongmao
# status code
# 200
# Zhonghua Chuanshuo Meide Gushi
# status code
# 200
# Zhonghua Da Jiangtan
# status code
# 200
# Zhonghua Deyu Gushi
# status code
# 200
# Zhonghua Dizi Gui
# status code
# 200
# Zhonghua Dizi Gui 2nd Season
# status code
# 200
# Zhonghua Lishi Wenhua Mingren
# status code
# 200
# Zhonghua Lizhi Lu
# status code
# 200
# Zhonghua Meide
# status code
# 200
# Zhonghua Meide Gushi: Chengxin Pian
# status code
# 200
# Zhonghua Wuqian Nian
# status code
# 200
# Zhonghua Xiao Yue Yun
# status code
# 200
# Zhonghua Xun Lixian Ji
# status code
# 200
# Zhongji Da Maoxian
# status code
# 200
# Zhongkui
# status code
# 200
# Zhongkui Chuanqi: Sui Han Sanyou
# status code
# 200
# status code
# 429
# status code
# 429
# status code
# 429
# Zhongshan Hun
# status code
# 200
# Zhongwai Mingren Chengzhang Gushi
# status code
# 200
# Zhongyuan Zhi Xing
# status code
# 200
# Zhou Zhou Lu Zhi Meng
# status code
# 200
# Zhou Zhou Lu Zhi Meng: Jiayuan Shouhu
# status code
# 200
# Zhouyi Zhou Liu
# status code
# 200
# Zhu Bajie Chi Xigua
# status code
# 200
# Zhu Cheng Man Youji
# status code
# 200
# Zhu Dike: Caihong Jiejie Jiang Gushi
# status code
# 200
# Zhu Dike: Guguai Dao Da Maoxian I
# status code
# 200
# Zhu Dike: Guguai Dao Da Maoxian II
# status code
# 200
# Zhu Dike: Lanhai Gi Yuan
# status code
# 200
# Zhu Dike: Mengxiang Xunlian Ying
# status code
# 200
# Zhu Tian Ji
# status code
# 200
# Zhu Xian
# status code
# 200
# Zhu Zai Yang Mei Xun Lin Ji
# status code
# 200
# Zhu Zhu Jili Xiao Caishen
# status code
# 200
# Zhu Zhu Xia: Bai Bian Lian Meng
# status code
# 200
# Zhu Zhu Xia: Bian Shen Xiao Ying Xiong
# status code
# 200
# Zhu Zhu Xia: Bian Shen Zhandu
# status code
# 200
# Zhu Zhu Xia: Bukesiyi de Shijie
# status code
# 200
# Zhu Zhu Xia: Chao Xing Meng Chong
# status code
# 200
# Zhu Zhu Xia: Da Nao Huang Gong
# status code
# 200
# Zhu Zhu Xia: Fan Wai - Pin Zhuang Tegong Dui
# status code
# 200
# Zhu Zhu Xia: Fan Wai - Zhi Huanqiu Riji
# status code
# 200
# Zhu Zhu Xia: Guang Ming Shou Wei Zhe
# status code
# 200
# Zhu Zhu Xia: Jimu Shijie de Tonghua
# status code
# 200
# Zhu Zhu Xia: Jing Qiu Xiao Yingxiong
# status code
# 200
# Zhu Zhu Xia: Jing Su Xiao Yingxiong
# status code
# 200
# Zhu Zhu Xia: Jiong Jiong Wei Ji
# status code
# 200
# Zhu Zhu Xia: Kele Ba
# status code
# 200
# Zhu Zhu Xia: Konglong Riji
# first
# 501
# last
# 550
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Zhu Zhu Xia: Meng Xiang Shou Wei Zhe
# status code
# 200
# Zhu Zhu Xia: Mo Huan Zhu Luo Ji
# status code
# 200
# Zhu Zhu Xia: Shenhai Xiao Yingxiong
# status code
# 200
# Zhu Zhu Xia: Wu Ling Shou Wei Zhe
# status code
# 200
# Zhu Zhu Xia: Wu Xia 2008
# status code
# 200
# Zhu Zhu Xia: Xingfu Jiuyuan Dui
# status code
# 200
# Zhu Zhu Xia: Ying Xiong Zhu Shao Nian
# status code
# 200
# Zhu Zhu Xia: Yong Chuang Juren Dao
# status code
# 200
# Zhu Zhu Xia: Yong Chuang Weilai Cheng
# status code
# 200
# status code
# 429
# Zhu Zhu Xia: Zhong Ji Jue Zhan
# status code
# 200
# Zhu Zhu Xia: Zhong Ji Jue Zhan - Qian Ye Pian
# status code
# 200
# Zhuan A
# status code
# 200
# Zhuang Chen Fan Dou Zhan Che
# status code
# 200
# Zhuangzai Koudai Lide Baba
# status code
# 200
# Zhuangzi Shuo
# status code
# 200
# Zhuanzhan Chao Xuan Doushi: Chao Xuan Juexing
# status code
# 200
# Zhuanzhan Zhi Chao Xuan Doushi
# status code
# 200
# Zhugong Zai Na
# status code
# 200
# Zhui Feng Shaonu
# status code
# 200
# Zhui Meng Shaonian
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Zhui Meng Zhe
# status code
# 200
# Zhui Shu
# status code
# 200
# Zhui Xu
# status code
# 200
# Zhuo Mi Cang
# status code
# 200
# Zi Baobao Leyuan
# status code
# 200
# Zi Chuan
# status code
# 200
# Zi Chuan: Yincang Hudong Ju
# status code
# 200
# Zi Sheng Chuanqi
# status code
# 200
# Zi Zuo Zi Shou
# status code
# 200
# Ziggy: Soreyuke! R&R Band
# status code
# 200
# Zigi
# status code
# 200
# Zigu Yingxiong Chu Shaonian
# status code
# 200
# Zinba
# status code
# 200
# ZIP! x Peeping Life TV: Cool Japan Saizensen
# status code
# 200
# Zipang
# status code
# 200
# Zipangu
# status code
# 200
# Zo Zo Zo Zombie-kun
# status code
# 200
# Zo Zo Zo Zombie-kun (TV)
# status code
# 200
# Zoids
# status code
# 429
# status code
# 200
# Zoids Fuzors
# status code
# 200
# Zoids Genesis
# status code
# 200
# Zoids Shinseiki/Zero
# status code
# 200
# Zoids Wild
# status code
# 200
# Zoids Wild Senki
# status code
# 200
# Zoids Wild Zero
# status code
# 200
# Zoku Attacker You! Kin Medal e no Michi
# status code
# 200
# Zoku Gosenzo San'e
# status code
# 200
# Zoku Koihime
# status code
# 200
# Zoku Naniwa Yuukyouden
# status code
# 200
# Zoku Natsume Yuujinchou
# first
# 551
# last
# 600
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# sleeping
# status code
# 200
# Zoku Natsume Yuujinchou: 3D Nyanko-sensei Gekijou
# status code
# 200
# Zoku Oujo & Onna Kishi W Do Gehin Roshutsu: Chijoku no Misemono Dorei
# status code
# 200
# Zoku Owarimonogatari
# status code
# 200
# Zoku Sayonara Zetsubou Sensei
# status code
# 200
# Zoku Sayonara Zetsubou Sensei: Shuukan Zetsubou Sensei Hihyou
# status code
# 200
# Zoku Touken Ranbu: Hanamaru
# status code
# 200
# Zoku Zou no Senaka: Baton Touch
# status code
# 200
# Zokuzoku Mura no Obake-tachi
# status code
# 200
# Zom 100: Zombie ni Naru made ni Shitai 100 no Koto
# status code
# 200
# Zom 100: Zombie ni Naru made ni Shitai 100 no Koto Recap
# status code
# 200
# Zombie Dumb
# status code
# 200
# Zombie Dumb 2
# status code
# 200
# Zombie Dumb 3
# status code
# 200
# Zombie Ehon
# status code
# 200
# Zombie-Loan
# status code
# 200
# Zombie-Loan Specials
# status code
# 200
# Zombieland Saga
# status code
# 200
# Zombieland Saga Movie
# status code
# 200
# Zombieland Saga Revenge
# status code
# 200
# Zone of the Enders: 2167 Idolo
# status code
# 200
# Zone of the Enders: Dolores, I
# status code
# 200
# Zone: Intro
# status code
# 200
# Zoning Tokyo
# status code
# 200
# Zonmi-chan: Halloween☆Special Movie!
# status code
# 200
# Zonmi-chan: Meat Pie of the Dead
# status code
# 200
# Zoo: Hidamari no Shi
# status code
# 200
# Zoobles!
# status code
# 200
# Zoojazoo "Watashi no Onaka"
# status code
# 200
# Zou da Zou
# status code
# 200
# Zou no Inai Doubutsuen
# status code
# 200
# Zou no Senaka: Tabidatsu Hi
# status code
# 200
# Zounds
# status code
# 429
# status code
# 429
# status code
# 429
# status code
# 200
# Zouressha ga Yatte Kita
# status code
# 200
# Zton Jingai Animation: A Beautiful Greed Nulu Nulu
# status code
# 200
# Zui Ke Ai De Ren
# status code
# 200
# Zui Ke Ai De Ren (Movie)
# status code
# 200
# Zui Qiang Woniu Busuzhike
# status code
# 200
# Zuiba, Erduo He Yanjing
# status code
# 200
# Zuihou de Zhaohuan Shi
# status code
# 200
# Zujou Kazoku Cavigliano
# status code
# 200
# Zukkoke Knight: Don De La Mancha
# status code
# 200
# Zukkoke Sannin-gumi no Bousai Kyoushitsu
# status code
# 200
# Zukkoke Sannin-gumi no Hi Asobi Boushi Daisakusen
# status code
# 200
# Zukkoke Sannin-gumi no Jitensha Kyoushitsu
# status code
# 200
# Zukkoke Sannin-gumi no Koutsuu Anzen
# status code
# 200
# Zukkoke Sannin-gumi: Kusunoki Yashiki no Guruguru-sama
# status code
# 200
# Zukkoke Sannin-gumi: Zukkoke Jikuu Bouken
# status code
# 200
# Zumomo to Nupepe
# status code
# 200
# Zunda Horizon
# status code
# 200
# Zuori Qing Kong
# first
# 601
# last
# 650
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}
# status code
# 200
# Zuori Qing Kong Pilot
# status code
# 200
# Zuoshou Shanglan
# status code
# 200
# Zuoyou Nao Zhili Kaifa
# status code
# 200
# Zuqiu Jianghu
# status code
# 200
# Zuqiu Wangzhe
# status code
# 200
# Zurui Maboroshi
# status code
# 200
# Zutto Mae kara Suki deshita. Kokuhaku Jikkou Iinkai
# status code
# 200
# status code
# 429
# Zutto Mae kara Suki deshita. Kokuhaku Jikkou Iinkai: Kinyoubi no Ohayou
# status code
# 200
# Zutto Suki Datta
# status code
# 200
# Zutto Tomodachi
# first
# 651
# last
# 660
# doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# clearrrrrrrrr
# {}

# %%
def mergedict(a,b):
    a.update(b)
    return a

 
def csvfile(details):
    field_names = ['Id','title', 'link','code', 'Rank','Popularity','Members','Score','summary','Studio','Episode','Producer','Licensor:','Genre','Theme','Duration','imgsrc'] 
    print("doneeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee")
    
    with open("anime_details.csv","a",encoding="utf-8") as f:
        w = csv.DictWriter( f, field_names )
        w.writeheader()
        for k,d in sorted(details.items()):
            w.writerow(mergedict({'Id': k},d))

# %%
def reviewst(reviews):
    fields = ['code','username','summary'] 
    with open("review_details.csv","a",encoding="utf-8") as f:
        w = csv.DictWriter(f, fields )
        w.writeheader()
        for key,val in sorted(reviews.items()):
            for k,v in val.items():
                w.writerow({'code':key,'username':k,'summary':v})

# %%
names=[]
href=[]
details={}
Allreviews={}
    
Detailscounter=0
